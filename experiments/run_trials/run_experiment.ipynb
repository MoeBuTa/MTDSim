# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_model, single_mtd_simulation, mtd_ai_simulation, multiple_mtd_simulation, specific_multiple_mtd_simulation
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging
import pandas as pd
import numpy as np
from math import pi
import matplotlib.pyplot as plt
from run_experiment import Experiment

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
# Learning Parameters
epsilon = 1.0  # exploration rate

# Simulator Settings
start_time = 0
finish_time = 15000
mtd_interval = [50]

network_size = [150]
total_nodes = 150
new_network = True

trial = 1500

mtd_strategies = [
    CompleteTopologyShuffle,
    # HostTopologyShuffle,
    IPShuffle,
    OSDiversity,
    # PortShuffle,
    # OSDiversityAssignment,
    ServiceDiversity,
    # UserShuffle
]

result_head_path = '/Users/williamho/Documents/GitHub/MTDSim'
static_degrade_factor = 2000

# %%
# result = Experiment(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network, "all_features", trial,result_head_path)
# result.raw_result_stats_pipeline('nomtd',run_trial = True, stats_type = 'median')
# for scheme in result.schemes:
#     result.raw_result_stats_pipeline(scheme,run_trial = True, stats_type = 'median')

# %%
model = "simultaneous"
result = Experiment(model,epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network, "model", trial, result_head_path, mtd_strategies=mtd_strategies, static_degrade_factor=static_degrade_factor)

result.run_trials(model)
# Out:
# Trial_ 0
# simultaneous
# simultaneous
# Trial_ 1
# simultaneous
# simultaneous
# Trial_ 2
# simultaneous
# simultaneous
# Trial_ 3
# simultaneous
# simultaneous
# Trial_ 4
# simultaneous
# simultaneous
# Trial_ 5
# simultaneous
# simultaneous
# Trial_ 6
# simultaneous
# simultaneous
# Trial_ 7
# simultaneous
# simultaneous
# Trial_ 8
# simultaneous
# simultaneous
# Trial_ 9
# simultaneous
# simultaneous
# Trial_ 10
# simultaneous
# simultaneous
# Trial_ 11
# simultaneous
# simultaneous
# Trial_ 12
# simultaneous
# simultaneous
# Trial_ 13
# simultaneous
# simultaneous
# Trial_ 14
# simultaneous
# simultaneous
# Trial_ 15
# simultaneous
# simultaneous
# Trial_ 16
# simultaneous
# simultaneous
# Trial_ 17
# simultaneous
# simultaneous
# Trial_ 18
# simultaneous
# simultaneous
# Trial_ 19
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/GitHub/MTDSim/mtdnetwork/operation/mtd_operation.py:169, in MTDOperation._mtd_execute_action(self, env, mtd)
#     168 # execute mtd
# --> 169 mtd.mtd_operation(self.attack_operation.get_adversary())
#     171 finish_time = env.now + self._proceed_time
#
# File ~/Documents/GitHub/MTDSim/mtdnetwork/mtd/completetopologyshuffle.py:19, in CompleteTopologyShuffle.mtd_operation(self, adversary)
#      18 # Regenerate the network graph
# ---> 19 self.network.gen_graph()
#      20 for host_id, host_instance in hosts.items():
#
# File ~/Documents/GitHub/MTDSim/mtdnetwork/component/network.py:184, in Network.gen_graph(self, min_nodes_per_subnet, max_subnets_per_layer, subnet_m_ratio, prob_inter_layer_edge)
#     182 node_id += s_nodes
# --> 184 subgraph_pos = nx.spring_layout(subgraph)
#     185 if i != 0:
#
# File <class 'networkx.utils.decorators.argmap'> compilation 16:4, in argmap_spring_layout_13(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/layout.py:491, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     490         k = dom_size / np.sqrt(nnodes)
# --> 491     pos = _fruchterman_reingold(
#     492         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     493     )
#     494 if fixed is None and scale is not None:
#
# File <class 'networkx.utils.decorators.argmap'> compilation 20:4, in argmap__fruchterman_reingold_17(A, k, pos, fixed, iterations, threshold, dim, seed)
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/layout.py:553, in _fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     552 length = np.where(length < 0.01, 0.1, length)
# --> 553 delta_pos = np.einsum("ij,i->ij", displacement, t / length)
#     554 if fixed is not None:
#     555     # don't change positions of fixed nodes
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/einsumfunc.py:1001, in _einsum_dispatcher(out, optimize, *operands, **kwargs)
#     998     return (path, path_print)
# -> 1001 def _einsum_dispatcher(*operands, out=None, optimize=None, **kwargs):
#    1002     # Arguably we dispatch on more arguments than we really should; see note in
#    1003     # _einsum_path_dispatcher for why.
#    1004     yield from operands
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/GitHub/MTDSim/mtdnetwork/operation/mtd_operation.py:124, in MTDOperation._mtd_batch_trigger_action(self)
#     123                 logging.info('MTD: %s triggered %.1fs' % (mtd.get_name(), self.env.now + self._proceed_time))
# --> 124             yield self.env.process(self._mtd_execute_action(env=self.env, mtd=mtd))
#     125 else:
#     126     # register and trigger all MTDs
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 model = "simultaneous"
#       2 result = Experiment(model,epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network, "model", trial, result_head_path, mtd_strategies=mtd_strategies, static_degrade_factor=static_degrade_factor)
# ----> 4 result.run_trials(model)
#
# File ~/Documents/GitHub/MTDSim/experiments/run_experiment.py:105, in Experiment.run_trials(self, scheme)
#     101         mtd = mtd_ai_simulation(self.features,self.model, self.model_path, self.start_time, self.finish_time, self.total_nodes, new_network = self.new_network,
#     102                                                     mtd_interval=self.mtd_interval,network_size=self.network_size ,custom_strategies=self.mtd_strategies, static_degrade_factor = self.static_degrade_factor)
#     104     else:
# --> 105         mtd = specific_multiple_mtd_simulation(scheme, self.mtd_strategies, scheme, mtd_interval=self.mtd_interval,network_size=self.network_size)
#     106 return
#
# File ~/Documents/GitHub/MTDSim/experiments/run.py:280, in specific_multiple_mtd_simulation(file_name, combination, scheme, mtd_interval, network_size)
#     278 for mtd_interval in mtd_interval:
#     279     for network_size in network_size:
# --> 280         evaluation = execute_simulation(scheme=scheme, mtd_interval=mtd_interval,
#     281                                         custom_strategies=combination, total_nodes=network_size)
#     282         # evaluation_results = evaluation.evaluation_result_by_compromise_checkpoint()
#     283         evaluation_results = evaluation.evaluation_result_by_compromise_checkpoint([0.05, 0.1, 0.15, 0.2, 0.25])
#
# File ~/Documents/GitHub/MTDSim/experiments/run.py:363, in execute_simulation(start_time, finish_time, scheme, mtd_interval, custom_strategies, checkpoints, total_nodes, total_endpoints, total_subnets, total_layers, target_layer, total_database, terminate_compromise_ratio, new_network)
#     361     env.run(until=(finish_time - start_time))
#     362 else:
# --> 363     env.run(until=end_event)
#     365 evaluation = Evaluation(network=time_network, adversary=adversary, security_metrics_record = security_metrics_record)
#     367 # sim_item = scheme
#     368 # if scheme == 'single':
#     369 #     sim_item = custom_strategies().get_name()
#    (...)
#     372 # time_network.get_mtd_stats().save_record(sim_time=mtd_interval, scheme=sim_item)
#     373 # adversary.get_attack_stats().save_record(sim_time=mtd_interval, scheme=sim_item)
#
# File ~/anaconda3/lib/python3.11/site-packages/simpy/core.py:246, in Environment.run(self, until)
#     244 try:
#     245     while True:
# --> 246         self.step()
#     247 except StopSimulation as exc:
#     248     return exc.args[0]  # == until.value
#
# File ~/anaconda3/lib/python3.11/site-packages/simpy/core.py:204, in Environment.step(self)
#     202 exc = type(event._value)(*event._value.args)
#     203 exc.__cause__ = event._value
# --> 204 raise exc
#
# KeyboardInterrupt:

# %%
# static_features = ["host_compromise_ratio", "total_number_of_ports", "attack_path_exposure",  "overall_asr_avg", "roa", "shortest_path_variability", "risk"]
# time_features = ["mtd_freq", "overall_mttc_avg", "time_since_last_mtd"]

# features = static_features + time_features
# for model in features:

#     print(model)
#     result = Experiment(model, epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network, model, trial, result_head_path)
#     result.run_trials(model)

# %%
# # static_features = [ "overall_asr_avg", "attack_path_exposure"]
# static_features = []
# time_features = ["overall_mttc_avg"]
# metrics =  static_features + time_features


# for metric in metrics:
#     models = [
#         f"{metric}",
#         # f"{metric}_CompleteTopologyShuffle",
#         # f"{metric}_IPShuffle",
#         # f"{metric}_OSDiversity",
#         # f"{metric}_ServiceDiversity"
#     ]

#     mtd_strategies_dict = {
#         'CompleteTopologyShuffle': CompleteTopologyShuffle,
#         'IPShuffle': IPShuffle,
#         'OSDiversity': OSDiversity,
#         'ServiceDiversity': ServiceDiversity
#     }

#     for model in models:
#         # Extract strategy from model string
#         strategy_name = model.split('_')[-1]
        
#         # Find corresponding MTD strategy
#         mtd_strategy = mtd_strategies_dict.get(strategy_name, None)
        
#         if not mtd_strategy:
#             print(f"Strategy {strategy_name} not found in mtd_strategies_dict.")
#             continue
        
#         print(f"Running model: {model} with strategy: {strategy_name}")
        
#         # Create Experiment instance with the MTD strategy
#         result = Experiment(epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path, mtd_strategies=[mtd_strategy])
        
#         # Run trials
#         result.run_trials(model)
