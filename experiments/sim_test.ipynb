# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_simulation
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
evaluation = execute_ai_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100, new_network=True)
# Out:
# `lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# `lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Action: 0
# Action: 1
# MTD: OSDiversity triggered 0.0s
# Action: 0
# Action: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 200.4s
# MTD: Interrupted EXPLOIT_VULN at 320.6s!
# Action: 1
# MTD: IPShuffle triggered 401.9s
# MTD: Interrupted EXPLOIT_VULN at 512.2s!
# Action: 1
# MTD: CompleteTopologyShuffle triggered 602.4s
# MTD: Interrupted EXPLOIT_VULN at 723.1s!
# Action: 1
# MTD: OSDiversity triggered 802.6s
# Action: 1
# MTD: OSDiversity triggered 1004.1s
# Action: 0
# Action: 1
# MTD: OSDiversity triggered 1204.8s
# Action: 1
# MTD: IPShuffle triggered 1404.9s
# MTD: Interrupted EXPLOIT_VULN at 1515.8s!
# Action: 0
# Action: 0
# Action: 1
# MTD: OSDiversity triggered 1605.3s
# Action: 0
# Action: 1
# MTD: IPShuffle triggered 1806.3s
# MTD: Interrupted EXPLOIT_VULN at 1916.5s!
# Action: 1
# MTD: IPShuffle triggered 2007.0s
# MTD: Interrupted EXPLOIT_VULN at 2117.1s!
# Action: 0
# Action: 0
# Action: 1
# MTD: OSDiversity triggered 2207.7s
# Action: 1
# MTD: OSDiversity triggered 2407.8s
# Action: 0
# Action: 0
# Action: 1
# MTD: ServiceDiversity triggered 2608.0s
# Action: 0
# Action: 0
# Action: 0
# Action: 0
# Action: 1
# MTD: IPShuffle triggered 2808.5s
# MTD: Interrupted EXPLOIT_VULN at 2918.5s!

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100, new_network=True)
# Out:
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.0
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.42711904761904784
# Attack Success Rate: 0
# MTD Frequency: 0
# Time to Compromise: 0
# Time Since Last MTD: 0
# MTD: OSDiversity triggered 0.0s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.0
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4598849206349207
# Attack Success Rate: 0
# MTD Frequency: 0.012495107330985413
# Time to Compromise: 0
# Time Since Last MTD: 200.34151624912596
# MTD: IPShuffle triggered 200.3s
# MTD: Interrupted EXPLOIT_VULN at 310.4s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.0
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4521349206349206
# Attack Success Rate: 0
# MTD Frequency: 0.006442821578456238
# Time to Compromise: 0
# Time Since Last MTD: 200.27473645517006
# MTD: ServiceDiversity triggered 400.6s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.01
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4833690476190475
# Attack Success Rate: 0.2
# MTD Frequency: 0.006373307810654804
# Time to Compromise: 519.4231130760459
# Time Since Last MTD: 200.38713594252215
# MTD: OSDiversity triggered 601.0s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.02
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.44280952380952393
# Attack Success Rate: 0.24285714285714285
# MTD Frequency: 0.005870813468960104
# Time to Compromise: 627.6117823053471
# Time Since Last MTD: 200.1461456756191
# MTD: IPShuffle triggered 801.1s
# MTD: Interrupted EXPLOIT_VULN at 911.7s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.03
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4370357142857144
# Attack Success Rate: 0.273015873015873
# MTD Frequency: 0.005484274727202134
# Time to Compromise: 717.2613059452793
# Time Since Last MTD: 200.48365136784457
# MTD: IPShuffle triggered 1001.6s
# MTD: Interrupted SCAN_PORT at 1112.0s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4387857142857145
# Attack Success Rate: 0.27976190476190477
# MTD Frequency: 0.005395754725258383
# Time to Compromise: 810.5132952158597
# Time Since Last MTD: 200.04859390821866
# MTD: OSDiversity triggered 1201.7s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4285
# Attack Success Rate: 0.26785714285714285
# MTD Frequency: 0.005458180521448225
# Time to Compromise: 852.6067369615449
# Time Since Last MTD: 200.37042666855632
# MTD: CompleteTopologyShuffle triggered 1402.1s
# MTD: Interrupted EXPLOIT_VULN at 1522.2s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.43040873015873027
# Attack Success Rate: 0.2589285714285714
# MTD Frequency: 0.00525540303863602
# Time to Compromise: 892.0874174015809
# Time Since Last MTD: 200.7258097977135
# MTD: IPShuffle triggered 1602.8s
# MTD: Interrupted SCAN_PORT at 1712.9s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4324841269841271
# Attack Success Rate: 0.251984126984127
# MTD Frequency: 0.00525419281647538
# Time to Compromise: 937.4714900366059
# Time Since Last MTD: 201.15064574313737
# MTD: IPShuffle triggered 1803.9s
# MTD: Interrupted EXPLOIT_VULN at 1914.8s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.43085714285714294
# Attack Success Rate: 0.24906015037593984
# MTD Frequency: 0.005222402527122299
# Time to Compromise: 978.1695856085828
# Time Since Last MTD: 200.85794692859304
# MTD: IPShuffle triggered 2004.8s
# MTD: Interrupted EXPLOIT_VULN at 2115.0s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.04
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.42538095238095247
# Attack Success Rate: 0.24642857142857144
# MTD Frequency: 0.00520101079242345
# Time to Compromise: 1022.0620513364296
# Time Since Last MTD: 201.03064970875425
# MTD: IPShuffle triggered 2205.8s
# MTD: Interrupted EXPLOIT_VULN at 2316.1s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.05
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4389285714285714
# Attack Success Rate: 0.24259740259740262
# MTD Frequency: 0.005181090101465483
# Time to Compromise: 1223.6319348064146
# Time Since Last MTD: 200.79779341302537
# MTD: IPShuffle triggered 2406.6s
# MTD: Interrupted SCAN_PORT at 2516.7s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.06
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4472777777777777
# Attack Success Rate: 0.24259740259740262
# MTD Frequency: 0.005165593317437744
# Time to Compromise: 1240.7392180299448
# Time Since Last MTD: 200.20508217781753
# MTD: OSDiversity triggered 2606.8s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.08
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.43232539682539683
# Attack Success Rate: 0.25779324841824847
# MTD Frequency: 0.005207561334789873
# Time to Compromise: 1613.0462961976282
# Time Since Last MTD: 200.21059676120558
# MTD: IPShuffle triggered 2807.0s
# MTD: Interrupted EXPLOIT_VULN at 2918.5s!
