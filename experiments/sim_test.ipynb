# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
#from run import execute_simulation, create_experiment_snapshots
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100)
# Out:
# Adversary: Start SCAN_HOST at 0.0s.
# MTD: IPShuffle triggered 0.0s
# MTD: IPShuffle deployed in the network at 0.0s.
# Adversary: Processed SCAN_HOST at 5.0s.
# Adversary: Start ENUM_HOST at 5.0s.
# Adversary: Processed ENUM_HOST at 10.0s.
# Adversary: Start SCAN_PORT at 10.0s.
# Adversary: Processed SCAN_PORT at 35.0s.
# Adversary: Start EXPLOIT_VULN 680d395d-cdd8-4bd8-b60a-5d81be67b714 on host 0 at 35.0s.
# Adversary: Processed EXPLOIT_VULN 680d395d-cdd8-4bd8-b60a-5d81be67b714 on host 0 at 35.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d3f48337-4f7f-4460-80b4-93e71cf1ad7a on host 0 at 35.9s.
# Adversary: Processed EXPLOIT_VULN d3f48337-4f7f-4460-80b4-93e71cf1ad7a on host 0 at 38.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7e9c6f5a-0820-4c33-99d4-229028d31f10 on host 0 at 38.1s.
# Adversary: Processed EXPLOIT_VULN 7e9c6f5a-0820-4c33-99d4-229028d31f10 on host 0 at 41.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3363b28a-b740-49e8-b18f-8e8e8dd52646 on host 0 at 41.3s.
# Adversary: Processed EXPLOIT_VULN 3363b28a-b740-49e8-b18f-8e8e8dd52646 on host 0 at 43.6s.
# Adversary: Start EXPLOIT_VULN a965a017-ded3-43c6-8b0e-5b3bffc0ce68 on host 0 at 43.6s.
# Adversary: Processed EXPLOIT_VULN a965a017-ded3-43c6-8b0e-5b3bffc0ce68 on host 0 at 46.9s.
# Adversary: Start EXPLOIT_VULN 6351fcef-e956-4034-9a8b-8b9b86633a97 on host 0 at 46.9s.
# Adversary: Processed EXPLOIT_VULN 6351fcef-e956-4034-9a8b-8b9b86633a97 on host 0 at 50.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 37c46b03-9722-4e0b-9220-0ca69d7ef516 on host 0 at 50.0s.
# Adversary: Processed EXPLOIT_VULN 37c46b03-9722-4e0b-9220-0ca69d7ef516 on host 0 at 58.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c05182f5-5a7a-41e0-ab94-acd14db4110b on host 0 at 58.2s.
# Adversary: Processed EXPLOIT_VULN c05182f5-5a7a-41e0-ab94-acd14db4110b on host 0 at 69.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 0 at 69.1s.
# Adversary: Processed EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 0 at 78.0s.
# Adversary: Start EXPLOIT_VULN 06dfdac2-ebf6-4d48-a581-b6b7c4addb22 on host 0 at 78.0s.
# Adversary: Processed EXPLOIT_VULN 06dfdac2-ebf6-4d48-a581-b6b7c4addb22 on host 0 at 81.4s.
# Adversary: Start EXPLOIT_VULN 3ff5b5c7-ea19-406a-b03f-7ecbc4f45c38 on host 0 at 81.4s.
# Adversary: Processed EXPLOIT_VULN 3ff5b5c7-ea19-406a-b03f-7ecbc4f45c38 on host 0 at 84.4s.
# Adversary: Start EXPLOIT_VULN 229c6efe-9e13-4249-baa5-087ad7165efe on host 0 at 84.4s.
# Adversary: Processed EXPLOIT_VULN 229c6efe-9e13-4249-baa5-087ad7165efe on host 0 at 86.8s.
# Adversary: Start EXPLOIT_VULN f2e96285-7038-411a-849d-e7c4c6592124 on host 0 at 86.8s.
# Adversary: Processed EXPLOIT_VULN f2e96285-7038-411a-849d-e7c4c6592124 on host 0 at 94.5s.
# Adversary: Start EXPLOIT_VULN c0fe989d-6f26-44c0-b40a-fe03ee1e1a92 on host 0 at 94.5s.
# Adversary: Processed EXPLOIT_VULN c0fe989d-6f26-44c0-b40a-fe03ee1e1a92 on host 0 at 102.3s.
# Adversary: Start BRUTE_FORCE at 102.3s.
# MTD: IPShuffle finished in 110.2s at 110.2s.
# MTD: Interrupted BRUTE_FORCE at 110.2s!
# Adversary: Restarting with SCAN_HOST at 130.3s!
# Adversary: Start SCAN_HOST at 130.3s.
# Adversary: Processed SCAN_HOST at 135.3s.
# Adversary: Start ENUM_HOST at 135.3s.
# Adversary: Processed ENUM_HOST at 140.3s.
# Adversary: Start SCAN_PORT at 140.3s.
# Adversary: Processed SCAN_PORT at 165.3s.
# Adversary: Start EXPLOIT_VULN fe24d338-b6ed-4891-982e-1bf191ec3272 on host 0 at 165.3s.
# Adversary: Processed EXPLOIT_VULN fe24d338-b6ed-4891-982e-1bf191ec3272 on host 0 at 177.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN af42d13d-a490-471b-afe0-e4b03e63308a on host 0 at 177.6s.
# Adversary: Processed EXPLOIT_VULN af42d13d-a490-471b-afe0-e4b03e63308a on host 0 at 182.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c0fe989d-6f26-44c0-b40a-fe03ee1e1a92 on host 0 at 182.7s.
# Adversary: Processed EXPLOIT_VULN c0fe989d-6f26-44c0-b40a-fe03ee1e1a92 on host 0 at 189.9s.
# Adversary: Start EXPLOIT_VULN 6e098212-7ce1-4397-bade-f2120d257324 on host 0 at 189.9s.
# Adversary: Processed EXPLOIT_VULN 6e098212-7ce1-4397-bade-f2120d257324 on host 0 at 196.9s.
# Adversary: Start EXPLOIT_VULN 39f64728-a324-46b8-a280-a1611fed38a4 on host 0 at 196.9s.
# MTD: OSDiversity triggered 200.2s
# MTD: OSDiversity deployed in the network at 200.2s.
# Adversary: Processed EXPLOIT_VULN 39f64728-a324-46b8-a280-a1611fed38a4 on host 0 at 200.7s.
# Adversary: Start EXPLOIT_VULN d3e2407d-e1aa-4123-83cd-6715745754df on host 0 at 200.7s.
# Adversary: Processed EXPLOIT_VULN d3e2407d-e1aa-4123-83cd-6715745754df on host 0 at 209.8s.
# Adversary: Start EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 0 at 209.8s.
# Adversary: Processed EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 0 at 218.4s.
# Adversary: Start EXPLOIT_VULN 33b51b71-8d0c-4983-bf15-033c1664731b on host 0 at 218.4s.
# Adversary: Processed EXPLOIT_VULN 33b51b71-8d0c-4983-bf15-033c1664731b on host 0 at 222.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 84c2086a-dabe-4864-bf02-e48a200fa222 on host 0 at 222.6s.
# Adversary: Processed EXPLOIT_VULN 84c2086a-dabe-4864-bf02-e48a200fa222 on host 0 at 226.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN aa848f58-8dca-4c05-9631-85bc70387fb4 on host 0 at 226.8s.
# Adversary: Processed EXPLOIT_VULN aa848f58-8dca-4c05-9631-85bc70387fb4 on host 0 at 234.1s.
# Adversary: Start EXPLOIT_VULN 2918f757-fb3e-4397-add1-961eac387de0 on host 0 at 234.1s.
# Adversary: Processed EXPLOIT_VULN 2918f757-fb3e-4397-add1-961eac387de0 on host 0 at 250.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 0 has been compromised at 250.7s!
# Adversary: Start SCAN_NEIGHBOR at 250.7s.
# Adversary: Processed SCAN_NEIGHBOR at 255.7s.
# Adversary: Start ENUM_HOST at 255.7s.
# Adversary: Processed ENUM_HOST at 260.7s.
# Adversary: Start SCAN_PORT at 260.7s.
# MTD: OSDiversity finished in 80.2s at 280.3s.
# MTD: Interrupted SCAN_PORT at 280.3s!
# Adversary: Restarting with SCAN_PORT at 301.7s!
# Adversary: Start SCAN_PORT at 301.7s.
# Adversary: Processed SCAN_PORT at 326.7s.
# Adversary: Start EXPLOIT_VULN 91a0e4de-2165-4004-9303-a1192a458948 on host 29 at 326.7s.
# Adversary: Processed EXPLOIT_VULN 91a0e4de-2165-4004-9303-a1192a458948 on host 29 at 327.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0b26d9a0-7758-4519-b2c2-4444d7f78007 on host 29 at 327.4s.
# Adversary: Processed EXPLOIT_VULN 0b26d9a0-7758-4519-b2c2-4444d7f78007 on host 29 at 336.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e05d7e69-b4b3-43b9-9e56-005c0728896c on host 29 at 336.6s.
# Adversary: Processed EXPLOIT_VULN e05d7e69-b4b3-43b9-9e56-005c0728896c on host 29 at 348.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0964df38-0e0e-44ce-92fe-77043f7ef16f on host 29 at 348.3s.
# Adversary: Processed EXPLOIT_VULN 0964df38-0e0e-44ce-92fe-77043f7ef16f on host 29 at 349.9s.
# Adversary: Start EXPLOIT_VULN fdc5f16e-24b5-421e-bb94-610821f289d4 on host 29 at 349.9s.
# Adversary: Processed EXPLOIT_VULN fdc5f16e-24b5-421e-bb94-610821f289d4 on host 29 at 355.7s.
# Adversary: Start EXPLOIT_VULN 2063eeaf-bcc8-46ef-93ec-b5264c68249f on host 29 at 355.7s.
# Adversary: Processed EXPLOIT_VULN 2063eeaf-bcc8-46ef-93ec-b5264c68249f on host 29 at 356.2s.
# Adversary: Start EXPLOIT_VULN 831fd638-d7e7-4f16-9775-8878c067abf4 on host 29 at 356.2s.
# Adversary: Processed EXPLOIT_VULN 831fd638-d7e7-4f16-9775-8878c067abf4 on host 29 at 361.8s.
# Adversary: Start EXPLOIT_VULN c6c85e46-64c3-4c76-823c-d74f324a7975 on host 29 at 361.8s.
# Adversary: Processed EXPLOIT_VULN c6c85e46-64c3-4c76-823c-d74f324a7975 on host 29 at 367.6s.
# Adversary: Start EXPLOIT_VULN ebdd431f-2b11-48d7-a046-5dc94b08078f on host 29 at 367.6s.
# Adversary: Processed EXPLOIT_VULN ebdd431f-2b11-48d7-a046-5dc94b08078f on host 29 at 374.5s.
# Adversary: Start EXPLOIT_VULN a37bab9c-e64d-491a-99c1-6fc889cc25bf on host 29 at 374.5s.
# Adversary: Processed EXPLOIT_VULN a37bab9c-e64d-491a-99c1-6fc889cc25bf on host 29 at 381.7s.
# Adversary: Start EXPLOIT_VULN b60b5d27-0067-4549-888d-5b36e34a4515 on host 29 at 381.7s.
# Adversary: Processed EXPLOIT_VULN b60b5d27-0067-4549-888d-5b36e34a4515 on host 29 at 384.2s.
# Adversary: Start BRUTE_FORCE at 384.2s.
# MTD: OSDiversity triggered 400.2s
# MTD: OSDiversity deployed in the network at 400.2s.
# Adversary: Processed BRUTE_FORCE at 404.2s.
# Adversary: Start ENUM_HOST at 404.2s.
# Adversary: Processed ENUM_HOST at 409.2s.
# Adversary: Start SCAN_PORT at 409.2s.
# Adversary: Processed SCAN_PORT at 434.2s.
# Adversary: Start EXPLOIT_VULN 3538dd3b-cc6f-4f9e-80d7-d06b245c6e22 on host 21 at 434.2s.
# Adversary: Processed EXPLOIT_VULN 3538dd3b-cc6f-4f9e-80d7-d06b245c6e22 on host 21 at 435.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 816fbd2a-b521-46f0-89fb-00022cfc67e0 on host 21 at 435.0s.
# Adversary: Processed EXPLOIT_VULN 816fbd2a-b521-46f0-89fb-00022cfc67e0 on host 21 at 442.4s.
# Adversary: Start EXPLOIT_VULN 816fbd2a-b521-46f0-89fb-00022cfc67e0 on host 21 at 442.4s.
# Adversary: Processed EXPLOIT_VULN 816fbd2a-b521-46f0-89fb-00022cfc67e0 on host 21 at 452.6s.
# Adversary: Start EXPLOIT_VULN db1185b8-5c4b-4e92-bf20-d897bab3322a on host 21 at 452.6s.
# Adversary: Processed EXPLOIT_VULN db1185b8-5c4b-4e92-bf20-d897bab3322a on host 21 at 455.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 455.8s.
# Adversary: Processed EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 464.7s.
# Adversary: Start EXPLOIT_VULN 3e6b25ed-b180-47b5-a9d4-ab53f99fb49f on host 21 at 464.7s.
# Adversary: Processed EXPLOIT_VULN 3e6b25ed-b180-47b5-a9d4-ab53f99fb49f on host 21 at 470.4s.
# Adversary: Start BRUTE_FORCE at 470.4s.
# MTD: OSDiversity finished in 80.7s at 481.0s.
# MTD: Interrupted BRUTE_FORCE at 481.0s!
# Adversary: Restarting with SCAN_PORT at 501.5s!
# Adversary: Start SCAN_PORT at 501.5s.
# Adversary: Processed SCAN_PORT at 526.5s.
# Adversary: Start EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 526.5s.
# Adversary: Processed EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 537.2s.
# Adversary: Start BRUTE_FORCE at 537.2s.
# Adversary: Processed BRUTE_FORCE at 557.2s.
# Adversary: Start ENUM_HOST at 557.2s.
# Adversary: Processed ENUM_HOST at 562.2s.
# Adversary: Start SCAN_PORT at 562.2s.
# Adversary: Processed SCAN_PORT at 587.2s.
# Adversary: Start EXPLOIT_VULN b8ec8a82-9ed6-4be3-aa5b-7fe7d1e824e3 on host 1 at 587.2s.
# Adversary: Processed EXPLOIT_VULN b8ec8a82-9ed6-4be3-aa5b-7fe7d1e824e3 on host 1 at 588.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e02bb824-109e-418d-afcc-272c1250a0a1 on host 1 at 588.0s.
# Adversary: Processed EXPLOIT_VULN e02bb824-109e-418d-afcc-272c1250a0a1 on host 1 at 590.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9f706e6a-8397-423d-8186-61a27297a0ea on host 1 at 590.3s.
# Adversary: Processed EXPLOIT_VULN 9f706e6a-8397-423d-8186-61a27297a0ea on host 1 at 592.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 723e279f-8b58-42bc-a782-e061e0b568a8 on host 1 at 592.4s.
# MTD: CompleteTopologyShuffle triggered 600.7s
# MTD: CompleteTopologyShuffle deployed in the network at 600.7s.
# Adversary: Processed EXPLOIT_VULN 723e279f-8b58-42bc-a782-e061e0b568a8 on host 1 at 601.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5b85c6ac-919a-4487-aeb1-0e5f2a2cdcea on host 1 at 601.6s.
# Adversary: Processed EXPLOIT_VULN 5b85c6ac-919a-4487-aeb1-0e5f2a2cdcea on host 1 at 608.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a93f54fb-ac45-4c7b-9eb4-bfac08b14ac3 on host 1 at 608.5s.
# Adversary: Processed EXPLOIT_VULN a93f54fb-ac45-4c7b-9eb4-bfac08b14ac3 on host 1 at 611.0s.
# Adversary: Start EXPLOIT_VULN e5b4715c-587c-4113-885b-775687413c2d on host 1 at 611.0s.
# Adversary: Processed EXPLOIT_VULN e5b4715c-587c-4113-885b-775687413c2d on host 1 at 615.9s.
# Adversary: Start EXPLOIT_VULN 59db972c-1f31-4c42-98fc-82fdc2718152 on host 1 at 615.9s.
# Adversary: Processed EXPLOIT_VULN 59db972c-1f31-4c42-98fc-82fdc2718152 on host 1 at 620.9s.
# Adversary: Start EXPLOIT_VULN d72b70ae-8f9a-45fb-9a2e-c1524d24b795 on host 1 at 620.9s.
# Adversary: Processed EXPLOIT_VULN d72b70ae-8f9a-45fb-9a2e-c1524d24b795 on host 1 at 624.2s.
# Adversary: Start EXPLOIT_VULN 2a21cc5f-80ba-474b-bedd-db3c8fcb517f on host 1 at 624.2s.
# Adversary: Processed EXPLOIT_VULN 2a21cc5f-80ba-474b-bedd-db3c8fcb517f on host 1 at 631.7s.
# Adversary: Start EXPLOIT_VULN 0beabb8b-8e91-47b2-a8f5-d9eba67ce000 on host 1 at 631.7s.
# Adversary: Processed EXPLOIT_VULN 0beabb8b-8e91-47b2-a8f5-d9eba67ce000 on host 1 at 638.9s.
# Adversary: Start EXPLOIT_VULN 8abae3dc-b516-438e-b020-7c3cbc6fecc8 on host 1 at 638.9s.
# Adversary: Processed EXPLOIT_VULN 8abae3dc-b516-438e-b020-7c3cbc6fecc8 on host 1 at 640.7s.
# Adversary: Start EXPLOIT_VULN 63e250f1-60d2-4f11-81f8-f7189e862c61 on host 1 at 640.7s.
# Adversary: Processed EXPLOIT_VULN 63e250f1-60d2-4f11-81f8-f7189e862c61 on host 1 at 650.7s.
# Adversary: Start EXPLOIT_VULN 863c8264-128a-49aa-ad1d-f755d5079ed5 on host 1 at 650.7s.
# Adversary: Processed EXPLOIT_VULN 863c8264-128a-49aa-ad1d-f755d5079ed5 on host 1 at 658.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 1 has been compromised at 658.6s!
# Adversary: Start SCAN_NEIGHBOR at 658.6s.
# Adversary: Processed SCAN_NEIGHBOR at 663.6s.
# Adversary: Start ENUM_HOST at 663.6s.
# Adversary: Processed ENUM_HOST at 668.6s.
# Adversary: Start SCAN_PORT at 668.6s.
# Adversary: Processed SCAN_PORT at 693.6s.
# Adversary: Start EXPLOIT_VULN e94f1ca3-cd51-4154-a3ac-d042342b1470 on host 25 at 693.6s.
# Adversary: Processed EXPLOIT_VULN e94f1ca3-cd51-4154-a3ac-d042342b1470 on host 25 at 695.7s.
# Adversary: Start EXPLOIT_VULN ec63a80d-6378-41e2-a5d9-0f40e08e6eb2 on host 25 at 695.7s.
# Adversary: Processed EXPLOIT_VULN ec63a80d-6378-41e2-a5d9-0f40e08e6eb2 on host 25 at 697.3s.
# Adversary: Start EXPLOIT_VULN ccca460e-f688-480d-97fa-d0048a70b478 on host 25 at 697.3s.
# Adversary: Processed EXPLOIT_VULN ccca460e-f688-480d-97fa-d0048a70b478 on host 25 at 707.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e770c6ea-2b16-4c49-859e-bf1c410e9afc on host 25 at 707.4s.
# Adversary: Processed EXPLOIT_VULN e770c6ea-2b16-4c49-859e-bf1c410e9afc on host 25 at 713.9s.
# Adversary: Start EXPLOIT_VULN c7539284-df93-49b0-94ba-25abf2479e02 on host 25 at 713.9s.
# MTD: CompleteTopologyShuffle finished in 120.2s at 720.9s.
# MTD: Interrupted EXPLOIT_VULN at 720.9s!
# Adversary: Restarting with SCAN_HOST at 741.4s!
# Adversary: Start SCAN_HOST at 741.4s.
# Adversary: Processed SCAN_HOST at 746.4s.
# Adversary: Start ENUM_HOST at 746.4s.
# Adversary: Processed ENUM_HOST at 751.4s.
# Adversary: Start SCAN_PORT at 751.4s.
# Adversary: Processed SCAN_PORT at 776.4s.
# Adversary: Start EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 776.4s.
# Adversary: Processed EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 785.4s.
# Adversary: Start BRUTE_FORCE at 785.4s.
# MTD: IPShuffle triggered 800.9s
# MTD: IPShuffle deployed in the network at 800.9s.
# Adversary: Processed BRUTE_FORCE at 805.4s.
# Adversary: Start ENUM_HOST at 805.4s.
# Adversary: Processed ENUM_HOST at 810.4s.
# Adversary: Start SCAN_PORT at 810.4s.
# Adversary: Processed SCAN_PORT at 835.4s.
# Adversary: Start EXPLOIT_VULN ebdd431f-2b11-48d7-a046-5dc94b08078f on host 29 at 835.4s.
# Adversary: Processed EXPLOIT_VULN ebdd431f-2b11-48d7-a046-5dc94b08078f on host 29 at 842.1s.
# Adversary: Start EXPLOIT_VULN a37bab9c-e64d-491a-99c1-6fc889cc25bf on host 29 at 842.1s.
# Adversary: Processed EXPLOIT_VULN a37bab9c-e64d-491a-99c1-6fc889cc25bf on host 29 at 849.8s.
# Adversary: Start EXPLOIT_VULN 4a6c9605-9e3e-4d52-b471-ff3899e9c857 on host 29 at 849.8s.
# Adversary: Processed EXPLOIT_VULN 4a6c9605-9e3e-4d52-b471-ff3899e9c857 on host 29 at 855.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 72d39e9a-c278-41e9-b421-01a33ab88657 on host 29 at 855.1s.
# Adversary: Processed EXPLOIT_VULN 72d39e9a-c278-41e9-b421-01a33ab88657 on host 29 at 856.2s.
# Adversary: Host 29 has been compromised at 856.2s!
# Adversary: Start SCAN_NEIGHBOR at 856.2s.
# Adversary: Processed SCAN_NEIGHBOR at 861.2s.
# Adversary: Start ENUM_HOST at 861.2s.
# Adversary: Processed ENUM_HOST at 866.2s.
# Adversary: Start SCAN_PORT at 866.2s.
# Adversary: Processed SCAN_PORT at 891.2s.
# Adversary: Start EXPLOIT_VULN 4bf6a510-f78c-4923-9509-a9a40e789491 on host 60 at 891.2s.
# Adversary: Processed EXPLOIT_VULN 4bf6a510-f78c-4923-9509-a9a40e789491 on host 60 at 891.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 00682174-109c-409b-8125-dff92347375d on host 60 at 891.8s.
# Adversary: Processed EXPLOIT_VULN 00682174-109c-409b-8125-dff92347375d on host 60 at 899.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e802bc9c-fbac-4c1a-abed-ba1be6e7dc89 on host 60 at 899.3s.
# MTD: IPShuffle finished in 110.6s at 911.5s.
# MTD: Interrupted EXPLOIT_VULN at 911.5s!
# Adversary: Restarting with SCAN_HOST at 933.3s!
# Adversary: Start SCAN_HOST at 933.3s.
# Adversary: Processed SCAN_HOST at 938.3s.
# Adversary: Start ENUM_HOST at 938.3s.
# Adversary: Processed ENUM_HOST at 943.3s.
# Adversary: Start SCAN_PORT at 943.3s.
# Adversary: Processed SCAN_PORT at 968.3s.
# Adversary: Start EXPLOIT_VULN ec63a80d-6378-41e2-a5d9-0f40e08e6eb2 on host 25 at 968.3s.
# Adversary: Processed EXPLOIT_VULN ec63a80d-6378-41e2-a5d9-0f40e08e6eb2 on host 25 at 969.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e770c6ea-2b16-4c49-859e-bf1c410e9afc on host 25 at 969.6s.
# Adversary: Processed EXPLOIT_VULN e770c6ea-2b16-4c49-859e-bf1c410e9afc on host 25 at 976.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c7539284-df93-49b0-94ba-25abf2479e02 on host 25 at 976.0s.
# Adversary: Processed EXPLOIT_VULN c7539284-df93-49b0-94ba-25abf2479e02 on host 25 at 992.5s.
# Adversary: Start EXPLOIT_VULN 0e838400-cb75-406d-bdb5-7385497e02e7 on host 25 at 992.5s.
# MTD: ServiceDiversity triggered 1000.9s
# MTD: ServiceDiversity deployed in the network at 1000.9s.
# Adversary: Processed EXPLOIT_VULN 0e838400-cb75-406d-bdb5-7385497e02e7 on host 25 at 1012.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 539240d6-e1f1-46de-a0f5-0ca16725e470 on host 25 at 1012.7s.
# Adversary: Processed EXPLOIT_VULN 539240d6-e1f1-46de-a0f5-0ca16725e470 on host 25 at 1031.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 25 has been compromised at 1031.5s!
# Adversary: Start SCAN_NEIGHBOR at 1031.5s.
# Adversary: Processed SCAN_NEIGHBOR at 1036.5s.
# Adversary: Start ENUM_HOST at 1036.5s.
# Adversary: Processed ENUM_HOST at 1041.5s.
# Adversary: Start SCAN_PORT at 1041.5s.
# Adversary: Processed SCAN_PORT at 1066.5s.
# Adversary: Start EXPLOIT_VULN 34a33a98-c7e0-4f8d-8003-5250fb0953da on host 27 at 1066.5s.
# MTD: ServiceDiversity finished in 70.1s at 1071.1s.
# MTD: Interrupted EXPLOIT_VULN at 1071.1s!
# Adversary: Restarting with SCAN_PORT at 1091.7s!
# Adversary: Start SCAN_PORT at 1091.7s.
# Adversary: Processed SCAN_PORT at 1116.7s.
# Adversary: Start EXPLOIT_VULN 34a33a98-c7e0-4f8d-8003-5250fb0953da on host 27 at 1116.7s.
# Adversary: Processed EXPLOIT_VULN 34a33a98-c7e0-4f8d-8003-5250fb0953da on host 27 at 1125.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 75444e93-ed92-424d-b78e-f82b63699560 on host 27 at 1125.3s.
# Adversary: Processed EXPLOIT_VULN 75444e93-ed92-424d-b78e-f82b63699560 on host 27 at 1131.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5f48f411-0392-4814-aa12-dd64c7005e56 on host 27 at 1131.2s.
# Adversary: Processed EXPLOIT_VULN 5f48f411-0392-4814-aa12-dd64c7005e56 on host 27 at 1143.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9b8472fb-1d3d-4b12-acfc-5e902b71c2cd on host 27 at 1143.5s.
# Adversary: Processed EXPLOIT_VULN 9b8472fb-1d3d-4b12-acfc-5e902b71c2cd on host 27 at 1147.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN dfd6e713-a5f5-491d-8fbb-9b8c858296a3 on host 27 at 1147.8s.
# Adversary: Processed EXPLOIT_VULN dfd6e713-a5f5-491d-8fbb-9b8c858296a3 on host 27 at 1152.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a853a5cc-75bf-4b7c-98c3-0b97acaea2d0 on host 27 at 1152.2s.
# Adversary: Processed EXPLOIT_VULN a853a5cc-75bf-4b7c-98c3-0b97acaea2d0 on host 27 at 1156.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 296cddc4-6e7c-4391-8a9e-7a19c0dc9d96 on host 27 at 1156.8s.
# Adversary: Processed EXPLOIT_VULN 296cddc4-6e7c-4391-8a9e-7a19c0dc9d96 on host 27 at 1165.0s.
# Adversary: Start EXPLOIT_VULN bc279afc-1513-416b-8263-2db06a54b4ee on host 27 at 1165.0s.
# Adversary: Processed EXPLOIT_VULN bc279afc-1513-416b-8263-2db06a54b4ee on host 27 at 1171.4s.
# Adversary: Start EXPLOIT_VULN 843983f3-cbf6-407b-91ca-3f9ce9c5ab62 on host 27 at 1171.4s.
# Adversary: Processed EXPLOIT_VULN 843983f3-cbf6-407b-91ca-3f9ce9c5ab62 on host 27 at 1178.6s.
# Adversary: Start BRUTE_FORCE at 1178.6s.
# Adversary: Processed BRUTE_FORCE at 1198.6s.
# Adversary: Start ENUM_HOST at 1198.6s.
# MTD: OSDiversity triggered 1201.5s
# MTD: OSDiversity deployed in the network at 1201.5s.
# Adversary: Processed ENUM_HOST at 1203.6s.
# Adversary: Start SCAN_PORT at 1203.6s.
# Adversary: Processed SCAN_PORT at 1228.6s.
# Adversary: Start EXPLOIT_VULN 4b81a10f-9b58-4967-8b37-e03e0486b359 on host 26 at 1228.6s.
# Adversary: Processed EXPLOIT_VULN 4b81a10f-9b58-4967-8b37-e03e0486b359 on host 26 at 1229.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a0f2ed22-3a0e-4b14-9df3-f4ce0fc23989 on host 26 at 1229.5s.
# Adversary: Processed EXPLOIT_VULN a0f2ed22-3a0e-4b14-9df3-f4ce0fc23989 on host 26 at 1230.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 28677af5-7009-4bf0-b183-66352b5e1546 on host 26 at 1230.6s.
# Adversary: Processed EXPLOIT_VULN 28677af5-7009-4bf0-b183-66352b5e1546 on host 26 at 1235.8s.
# Adversary: Start EXPLOIT_VULN 1b44d450-b4cc-441f-9a96-b50d7895dbec on host 26 at 1235.8s.
# Adversary: Processed EXPLOIT_VULN 1b44d450-b4cc-441f-9a96-b50d7895dbec on host 26 at 1237.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2f924c0a-2c69-4bc1-8f15-690587526c0b on host 26 at 1237.9s.
# Adversary: Processed EXPLOIT_VULN 2f924c0a-2c69-4bc1-8f15-690587526c0b on host 26 at 1239.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN de8f0163-eba9-42dc-9f82-37a8495758d5 on host 26 at 1239.1s.
# Adversary: Processed EXPLOIT_VULN de8f0163-eba9-42dc-9f82-37a8495758d5 on host 26 at 1242.5s.
# Adversary: Start EXPLOIT_VULN 296cddc4-6e7c-4391-8a9e-7a19c0dc9d96 on host 26 at 1242.5s.
# Adversary: Processed EXPLOIT_VULN 296cddc4-6e7c-4391-8a9e-7a19c0dc9d96 on host 26 at 1251.0s.
# Adversary: Start EXPLOIT_VULN 75ef84eb-99f8-41a0-b5de-b3444723dcd5 on host 26 at 1251.0s.
# Adversary: Processed EXPLOIT_VULN 75ef84eb-99f8-41a0-b5de-b3444723dcd5 on host 26 at 1254.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 18dfb317-19ff-4689-9779-701fca46912a on host 26 at 1254.3s.
# Adversary: Processed EXPLOIT_VULN 18dfb317-19ff-4689-9779-701fca46912a on host 26 at 1259.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 625a2a02-e354-4056-b65a-e01b55c6e042 on host 26 at 1259.3s.
# Adversary: Processed EXPLOIT_VULN 625a2a02-e354-4056-b65a-e01b55c6e042 on host 26 at 1263.2s.
# Adversary: Start EXPLOIT_VULN d62c546b-96a5-4ae0-80e7-3cd5bfcb1d65 on host 26 at 1263.2s.
# Adversary: Processed EXPLOIT_VULN d62c546b-96a5-4ae0-80e7-3cd5bfcb1d65 on host 26 at 1266.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9828b761-d4de-4aed-8565-a3a7205f2e16 on host 26 at 1266.7s.
# MTD: OSDiversity finished in 80.0s at 1281.5s.
# MTD: Interrupted EXPLOIT_VULN at 1281.5s!
# Adversary: Restarting with SCAN_PORT at 1302.1s!
# Adversary: Start SCAN_PORT at 1302.1s.
# Adversary: Processed SCAN_PORT at 1327.1s.
# Adversary: Start EXPLOIT_VULN ed868025-aaa8-42ce-84ca-e41a919cf74c on host 26 at 1327.1s.
# Adversary: Processed EXPLOIT_VULN ed868025-aaa8-42ce-84ca-e41a919cf74c on host 26 at 1329.2s.
# Adversary: Start EXPLOIT_VULN 232f88a2-efb7-46b1-95ee-56f661c0c464 on host 26 at 1329.2s.
# Adversary: Processed EXPLOIT_VULN 232f88a2-efb7-46b1-95ee-56f661c0c464 on host 26 at 1334.5s.
# Adversary: Start EXPLOIT_VULN 21d6f72e-1bdd-4920-9fa1-b8f3fa1d29c9 on host 26 at 1334.5s.
# Adversary: Processed EXPLOIT_VULN 21d6f72e-1bdd-4920-9fa1-b8f3fa1d29c9 on host 26 at 1341.9s.
# Adversary: Start EXPLOIT_VULN 5aa075b3-3c51-4dd0-bada-e93a2393948e on host 26 at 1341.9s.
# Adversary: Processed EXPLOIT_VULN 5aa075b3-3c51-4dd0-bada-e93a2393948e on host 26 at 1349.7s.
# Adversary: Start EXPLOIT_VULN 6fed94c1-0df9-459a-9b1c-31aa8f8f4ccd on host 26 at 1349.7s.
# Adversary: Processed EXPLOIT_VULN 6fed94c1-0df9-459a-9b1c-31aa8f8f4ccd on host 26 at 1352.3s.
# Adversary: Start EXPLOIT_VULN 6259137a-5ec2-41b7-b3f5-eb3cb63574ca on host 26 at 1352.3s.
# Adversary: Processed EXPLOIT_VULN 6259137a-5ec2-41b7-b3f5-eb3cb63574ca on host 26 at 1355.3s.
# Adversary: Start EXPLOIT_VULN 58a5100d-5e93-4b72-9fc4-668b257218a6 on host 26 at 1355.3s.
# Adversary: Processed EXPLOIT_VULN 58a5100d-5e93-4b72-9fc4-668b257218a6 on host 26 at 1362.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e694d265-1804-4013-8ecf-d03a3ba39a69 on host 26 at 1362.8s.
# Adversary: Processed EXPLOIT_VULN e694d265-1804-4013-8ecf-d03a3ba39a69 on host 26 at 1369.6s.
# Adversary: Start EXPLOIT_VULN 26bd81cc-0d11-49f4-aff5-f3135c5783fa on host 26 at 1369.6s.
# Adversary: Processed EXPLOIT_VULN 26bd81cc-0d11-49f4-aff5-f3135c5783fa on host 26 at 1373.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6fed94c1-0df9-459a-9b1c-31aa8f8f4ccd on host 26 at 1373.8s.
# Adversary: Processed EXPLOIT_VULN 6fed94c1-0df9-459a-9b1c-31aa8f8f4ccd on host 26 at 1375.6s.
# Adversary: Start EXPLOIT_VULN 6259137a-5ec2-41b7-b3f5-eb3cb63574ca on host 26 at 1375.6s.
# Adversary: Processed EXPLOIT_VULN 6259137a-5ec2-41b7-b3f5-eb3cb63574ca on host 26 at 1378.1s.
# Adversary: Start EXPLOIT_VULN 58a5100d-5e93-4b72-9fc4-668b257218a6 on host 26 at 1378.1s.
# Adversary: Processed EXPLOIT_VULN 58a5100d-5e93-4b72-9fc4-668b257218a6 on host 26 at 1382.6s.
# Adversary: Start EXPLOIT_VULN e694d265-1804-4013-8ecf-d03a3ba39a69 on host 26 at 1382.6s.
# Adversary: Processed EXPLOIT_VULN e694d265-1804-4013-8ecf-d03a3ba39a69 on host 26 at 1388.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 26bd81cc-0d11-49f4-aff5-f3135c5783fa on host 26 at 1388.9s.
# Adversary: Processed EXPLOIT_VULN 26bd81cc-0d11-49f4-aff5-f3135c5783fa on host 26 at 1391.0s.
# Adversary: Start EXPLOIT_VULN 329bb568-e407-45eb-834b-706d5494ff1a on host 26 at 1391.0s.
# Adversary: Processed EXPLOIT_VULN 329bb568-e407-45eb-834b-706d5494ff1a on host 26 at 1396.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5d9c563b-a964-46c3-a3be-a6bd46c11ffa on host 26 at 1396.1s.
# Adversary: Processed EXPLOIT_VULN 5d9c563b-a964-46c3-a3be-a6bd46c11ffa on host 26 at 1399.2s.
# Adversary: Start EXPLOIT_VULN 2cd56fb3-54d8-4a76-8e96-c7757ab243ae on host 26 at 1399.2s.
# MTD: IPShuffle triggered 1401.7s
# MTD: IPShuffle deployed in the network at 1401.7s.
# Adversary: Processed EXPLOIT_VULN 2cd56fb3-54d8-4a76-8e96-c7757ab243ae on host 26 at 1402.1s.
# Adversary: Start EXPLOIT_VULN b55f1215-1ca3-4f24-ad24-e43e8bbe24f2 on host 26 at 1402.1s.
# Adversary: Processed EXPLOIT_VULN b55f1215-1ca3-4f24-ad24-e43e8bbe24f2 on host 26 at 1407.1s.
# Adversary: Start EXPLOIT_VULN da18e0c4-7434-4344-b6b9-3aa45537f3cb on host 26 at 1407.1s.
# Adversary: Processed EXPLOIT_VULN da18e0c4-7434-4344-b6b9-3aa45537f3cb on host 26 at 1429.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 442a1109-fe32-4aa0-bdf5-879a2fa15e47 on host 26 at 1429.4s.
# Adversary: Processed EXPLOIT_VULN 442a1109-fe32-4aa0-bdf5-879a2fa15e47 on host 26 at 1431.9s.
# Adversary: Start EXPLOIT_VULN 135e0697-27b2-4793-a8ab-3759430c0612 on host 26 at 1431.9s.
# Adversary: Processed EXPLOIT_VULN 135e0697-27b2-4793-a8ab-3759430c0612 on host 26 at 1435.6s.
# Adversary: Start EXPLOIT_VULN d93c4e76-4e6b-4146-8c0b-9c2cce095fe8 on host 26 at 1435.6s.
# Adversary: Processed EXPLOIT_VULN d93c4e76-4e6b-4146-8c0b-9c2cce095fe8 on host 26 at 1440.3s.
# Adversary: Start EXPLOIT_VULN 625a2a02-e354-4056-b65a-e01b55c6e042 on host 26 at 1440.3s.
# Adversary: Processed EXPLOIT_VULN 625a2a02-e354-4056-b65a-e01b55c6e042 on host 26 at 1444.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9828b761-d4de-4aed-8565-a3a7205f2e16 on host 26 at 1444.6s.
# Adversary: Processed EXPLOIT_VULN 9828b761-d4de-4aed-8565-a3a7205f2e16 on host 26 at 1464.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d7f300a7-bbdb-4c09-8c50-8031ef5027e6 on host 26 at 1464.4s.
# Adversary: Processed EXPLOIT_VULN d7f300a7-bbdb-4c09-8c50-8031ef5027e6 on host 26 at 1473.2s.
# Adversary: Start EXPLOIT_VULN 76626ecd-f940-4180-a193-68ddff747197 on host 26 at 1473.2s.
# Adversary: Processed EXPLOIT_VULN 76626ecd-f940-4180-a193-68ddff747197 on host 26 at 1475.9s.
# Adversary: Start EXPLOIT_VULN 2ba248be-f411-4da1-ad0c-43b04bae5354 on host 26 at 1475.9s.
# Adversary: Processed EXPLOIT_VULN 2ba248be-f411-4da1-ad0c-43b04bae5354 on host 26 at 1482.6s.
# Adversary: Start EXPLOIT_VULN a5ed86f7-c8d1-4591-941c-36f0f5a65da1 on host 26 at 1482.6s.
# Adversary: Processed EXPLOIT_VULN a5ed86f7-c8d1-4591-941c-36f0f5a65da1 on host 26 at 1505.3s.
# Adversary: Start EXPLOIT_VULN ba9e462a-9f52-4fa4-a97f-d19a464be81c on host 26 at 1505.3s.
# MTD: IPShuffle finished in 110.9s at 1512.6s.
# MTD: Interrupted EXPLOIT_VULN at 1512.6s!
# Adversary: Restarting with SCAN_HOST at 1532.8s!
# Adversary: Start SCAN_HOST at 1532.8s.
# Adversary: Processed SCAN_HOST at 1537.8s.
# Adversary: Start ENUM_HOST at 1537.8s.
# Adversary: Processed ENUM_HOST at 1542.8s.
# Adversary: Start SCAN_PORT at 1542.8s.
# Adversary: Processed SCAN_PORT at 1567.8s.
# Adversary: Start EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 1567.8s.
# Adversary: Processed EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 1577.6s.
# Adversary: Start BRUTE_FORCE at 1577.6s.
# Adversary: Processed BRUTE_FORCE at 1597.6s.
# Adversary: Start ENUM_HOST at 1597.6s.
# MTD: IPShuffle triggered 1602.6s
# MTD: IPShuffle deployed in the network at 1602.6s.
# Adversary: Processed ENUM_HOST at 1602.6s.
# Adversary: Start SCAN_PORT at 1602.6s.
# Adversary: Processed SCAN_PORT at 1627.6s.
# Adversary: Start EXPLOIT_VULN 05860a46-5880-49cf-b48e-eea0fe15e9f9 on host 43 at 1627.6s.
# Adversary: Processed EXPLOIT_VULN 05860a46-5880-49cf-b48e-eea0fe15e9f9 on host 43 at 1628.0s.
# Adversary: Start EXPLOIT_VULN 78ed3fc8-cb93-47b3-a019-3f5a256b5bff on host 43 at 1628.0s.
# Adversary: Processed EXPLOIT_VULN 78ed3fc8-cb93-47b3-a019-3f5a256b5bff on host 43 at 1632.2s.
# Adversary: Start EXPLOIT_VULN 0fa7ecf3-da1c-4a59-9bca-30c51563dd9f on host 43 at 1632.2s.
# Adversary: Processed EXPLOIT_VULN 0fa7ecf3-da1c-4a59-9bca-30c51563dd9f on host 43 at 1640.0s.
# Adversary: Start EXPLOIT_VULN c56f4214-7512-498c-9023-1833d9256fcb on host 43 at 1640.0s.
# Adversary: Processed EXPLOIT_VULN c56f4214-7512-498c-9023-1833d9256fcb on host 43 at 1645.6s.
# Adversary: Start EXPLOIT_VULN ff486c80-fd5d-4773-9eab-163057610a3f on host 43 at 1645.6s.
# Adversary: Processed EXPLOIT_VULN ff486c80-fd5d-4773-9eab-163057610a3f on host 43 at 1648.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c4dcf3bc-599b-414a-a753-c8e195f295d6 on host 43 at 1648.5s.
# Adversary: Processed EXPLOIT_VULN c4dcf3bc-599b-414a-a753-c8e195f295d6 on host 43 at 1655.8s.
# Adversary: Start EXPLOIT_VULN 4b40efee-28ba-4c14-af40-60168f7fe039 on host 43 at 1655.8s.
# Adversary: Processed EXPLOIT_VULN 4b40efee-28ba-4c14-af40-60168f7fe039 on host 43 at 1669.7s.
# Adversary: Start EXPLOIT_VULN 6f49bab7-8c42-4172-a879-34d2e1b4c3c7 on host 43 at 1669.7s.
# Adversary: Processed EXPLOIT_VULN 6f49bab7-8c42-4172-a879-34d2e1b4c3c7 on host 43 at 1678.0s.
# Adversary: Start EXPLOIT_VULN 9d7c2561-7fb5-4cbc-9454-218ad158ab4d on host 43 at 1678.0s.
# Adversary: Processed EXPLOIT_VULN 9d7c2561-7fb5-4cbc-9454-218ad158ab4d on host 43 at 1682.1s.
# Adversary: Start EXPLOIT_VULN cac65da2-4824-4f3a-94e6-f2e067560619 on host 43 at 1682.1s.
# Adversary: Processed EXPLOIT_VULN cac65da2-4824-4f3a-94e6-f2e067560619 on host 43 at 1684.3s.
# Adversary: Start EXPLOIT_VULN 135e0697-27b2-4793-a8ab-3759430c0612 on host 43 at 1684.3s.
# Adversary: Processed EXPLOIT_VULN 135e0697-27b2-4793-a8ab-3759430c0612 on host 43 at 1688.6s.
# Adversary: Start EXPLOIT_VULN 2b8ffa9b-5aa3-4474-87a0-531e406524c4 on host 43 at 1688.6s.
# Adversary: Processed EXPLOIT_VULN 2b8ffa9b-5aa3-4474-87a0-531e406524c4 on host 43 at 1701.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 43 at 1701.1s.
# MTD: IPShuffle finished in 110.7s at 1713.3s.
# MTD: Interrupted EXPLOIT_VULN at 1713.3s!
# Adversary: Restarting with SCAN_HOST at 1735.2s!
# Adversary: Start SCAN_HOST at 1735.2s.
# Adversary: Processed SCAN_HOST at 1740.2s.
# Adversary: Start ENUM_HOST at 1740.2s.
# Adversary: Processed ENUM_HOST at 1745.2s.
# Adversary: Start SCAN_PORT at 1745.2s.
# Adversary: Processed SCAN_PORT at 1770.2s.
# Adversary: Start EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 1770.2s.
# Adversary: Processed EXPLOIT_VULN 7a0920a5-fd6c-4c3f-b8c9-0da2481930e6 on host 21 at 1781.5s.
# Adversary: Start BRUTE_FORCE at 1781.5s.
# Adversary: Processed BRUTE_FORCE at 1801.5s.
# Adversary: Start ENUM_HOST at 1801.5s.
# MTD: CompleteTopologyShuffle triggered 1802.6s
# MTD: CompleteTopologyShuffle deployed in the network at 1802.6s.
# Adversary: Processed ENUM_HOST at 1806.5s.
# Adversary: Start SCAN_PORT at 1806.5s.
# Adversary: Processed SCAN_PORT at 1831.5s.
# Adversary: Start EXPLOIT_VULN 27c4c750-0b2a-4d67-9378-f37c3fbdc43c on host 14 at 1831.5s.
# Adversary: Processed EXPLOIT_VULN 27c4c750-0b2a-4d67-9378-f37c3fbdc43c on host 14 at 1836.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 821adcd0-413b-4aa1-97e4-a7f892d1d03a on host 14 at 1836.2s.
# Adversary: Processed EXPLOIT_VULN 821adcd0-413b-4aa1-97e4-a7f892d1d03a on host 14 at 1853.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f7c67cb2-e47a-4a9f-b280-1c902d084b0a on host 14 at 1853.8s.
# Adversary: Processed EXPLOIT_VULN f7c67cb2-e47a-4a9f-b280-1c902d084b0a on host 14 at 1858.3s.
# Adversary: Start EXPLOIT_VULN 3c14d0af-f175-4bc9-8e52-8d38bffd08e9 on host 14 at 1858.3s.
# Adversary: Processed EXPLOIT_VULN 3c14d0af-f175-4bc9-8e52-8d38bffd08e9 on host 14 at 1863.3s.
# Adversary: Start EXPLOIT_VULN bda663c9-1273-46e7-8d59-750187861dee on host 14 at 1863.3s.
# Adversary: Processed EXPLOIT_VULN bda663c9-1273-46e7-8d59-750187861dee on host 14 at 1870.2s.
# Adversary: Start EXPLOIT_VULN 7b644f6f-2bab-433f-ad41-1c57f7438af2 on host 14 at 1870.2s.
# Adversary: Processed EXPLOIT_VULN 7b644f6f-2bab-433f-ad41-1c57f7438af2 on host 14 at 1874.0s.
# Adversary: Start EXPLOIT_VULN c8a6ea04-b287-474a-9c0b-edd5f9a047b6 on host 14 at 1874.0s.
# Adversary: Processed EXPLOIT_VULN c8a6ea04-b287-474a-9c0b-edd5f9a047b6 on host 14 at 1876.8s.
# Adversary: Start EXPLOIT_VULN 01e1b388-10b6-4317-a397-88f4f2807a91 on host 14 at 1876.8s.
# Adversary: Processed EXPLOIT_VULN 01e1b388-10b6-4317-a397-88f4f2807a91 on host 14 at 1877.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4f1b6af0-1133-4551-863b-2830b1471ffe on host 14 at 1877.9s.
# Adversary: Processed EXPLOIT_VULN 4f1b6af0-1133-4551-863b-2830b1471ffe on host 14 at 1888.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 436caf4f-9259-42e9-97a7-1d2111ddd9b6 on host 14 at 1888.3s.
# Adversary: Processed EXPLOIT_VULN 436caf4f-9259-42e9-97a7-1d2111ddd9b6 on host 14 at 1890.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 83d274bb-291f-4dba-ada7-c004260ffaa5 on host 14 at 1890.7s.
# Adversary: Processed EXPLOIT_VULN 83d274bb-291f-4dba-ada7-c004260ffaa5 on host 14 at 1897.4s.
# Adversary: Start EXPLOIT_VULN cc381afd-8918-409d-8d3e-b981d721a745 on host 14 at 1897.4s.
# Adversary: Processed EXPLOIT_VULN cc381afd-8918-409d-8d3e-b981d721a745 on host 14 at 1905.2s.
# Adversary: Start EXPLOIT_VULN 50c510c4-3c93-419d-91fb-86d6db63fc36 on host 14 at 1905.2s.
# Adversary: Processed EXPLOIT_VULN 50c510c4-3c93-419d-91fb-86d6db63fc36 on host 14 at 1911.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8debfd40-cd22-4365-825f-86b03f00e123 on host 14 at 1911.7s.
# Adversary: Processed EXPLOIT_VULN 8debfd40-cd22-4365-825f-86b03f00e123 on host 14 at 1917.1s.
# Adversary: Start EXPLOIT_VULN 507e5a59-4a0f-493f-80c4-ba2b6af685f7 on host 14 at 1917.1s.
# MTD: CompleteTopologyShuffle finished in 120.3s at 1922.8s.
# MTD: Interrupted EXPLOIT_VULN at 1922.8s!
# Adversary: Restarting with SCAN_HOST at 1943.2s!
# Adversary: Start SCAN_HOST at 1943.2s.
# Adversary: Processed SCAN_HOST at 1948.2s.
# Adversary: Start ENUM_HOST at 1948.2s.
# Adversary: Processed ENUM_HOST at 1953.2s.
# Adversary: Start SCAN_PORT at 1953.2s.
# Adversary: Processed SCAN_PORT at 1978.2s.
# Adversary: Start BRUTE_FORCE at 1978.2s.
# Adversary: Processed BRUTE_FORCE at 1998.2s.
# Adversary: Start ENUM_HOST at 1998.2s.
# MTD: CompleteTopologyShuffle triggered 2003.0s
# MTD: CompleteTopologyShuffle deployed in the network at 2003.0s.
# Adversary: Processed ENUM_HOST at 2003.2s.
# Adversary: Start SCAN_PORT at 2003.2s.
# Adversary: Processed SCAN_PORT at 2028.2s.
# Adversary: Start EXPLOIT_VULN 50e5ff52-60f1-4738-ba3c-023ce5cd059f on host 71 at 2028.2s.
# Adversary: Processed EXPLOIT_VULN 50e5ff52-60f1-4738-ba3c-023ce5cd059f on host 71 at 2031.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c766bdb3-5d97-4f21-8658-fc16e317b484 on host 71 at 2031.1s.
# Adversary: Processed EXPLOIT_VULN c766bdb3-5d97-4f21-8658-fc16e317b484 on host 71 at 2032.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7dd230ec-0650-4dc7-8a95-4fad21a87443 on host 71 at 2032.5s.
# Adversary: Processed EXPLOIT_VULN 7dd230ec-0650-4dc7-8a95-4fad21a87443 on host 71 at 2039.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 90b64e03-ca33-41f8-94a4-27f4411f8541 on host 71 at 2039.5s.
# Adversary: Processed EXPLOIT_VULN 90b64e03-ca33-41f8-94a4-27f4411f8541 on host 71 at 2057.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7828c84e-12cf-4407-abba-01c157b10698 on host 71 at 2057.2s.
# Adversary: Processed EXPLOIT_VULN 7828c84e-12cf-4407-abba-01c157b10698 on host 71 at 2063.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3a9bf8fb-cf0c-4d64-b5c1-feb408975a35 on host 71 at 2063.3s.
# Adversary: Processed EXPLOIT_VULN 3a9bf8fb-cf0c-4d64-b5c1-feb408975a35 on host 71 at 2064.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN eb9a91de-8d64-46bb-866f-db2da28b449c on host 71 at 2064.8s.
# Adversary: Processed EXPLOIT_VULN eb9a91de-8d64-46bb-866f-db2da28b449c on host 71 at 2065.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN de42afe1-5575-4f53-a3dc-b810317b5006 on host 71 at 2065.6s.
# Adversary: Processed EXPLOIT_VULN de42afe1-5575-4f53-a3dc-b810317b5006 on host 71 at 2073.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d377b3f9-ab76-4c88-8e06-2e1bb4e19907 on host 71 at 2073.2s.
# Adversary: Processed EXPLOIT_VULN d377b3f9-ab76-4c88-8e06-2e1bb4e19907 on host 71 at 2080.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6078e283-e697-4e64-b0c8-412fbdd20279 on host 71 at 2080.1s.
# Adversary: Processed EXPLOIT_VULN 6078e283-e697-4e64-b0c8-412fbdd20279 on host 71 at 2085.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f7f06e40-fc5e-416e-b96b-b308221d18c9 on host 71 at 2085.7s.
# Adversary: Processed EXPLOIT_VULN f7f06e40-fc5e-416e-b96b-b308221d18c9 on host 71 at 2088.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b7ae789c-7419-459d-88e6-45ba6d175be6 on host 71 at 2088.3s.
# Adversary: Processed EXPLOIT_VULN b7ae789c-7419-459d-88e6-45ba6d175be6 on host 71 at 2090.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b487fda7-cb77-4dc9-a231-84581c0e5993 on host 71 at 2090.1s.
# Adversary: Processed EXPLOIT_VULN b487fda7-cb77-4dc9-a231-84581c0e5993 on host 71 at 2095.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 50e50728-0d56-4b89-b213-44c07f55d997 on host 71 at 2095.0s.
# Adversary: Processed EXPLOIT_VULN 50e50728-0d56-4b89-b213-44c07f55d997 on host 71 at 2100.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 057da7e9-cc2e-467e-b521-2c4d6f1949c1 on host 71 at 2100.0s.
# Adversary: Processed EXPLOIT_VULN 057da7e9-cc2e-467e-b521-2c4d6f1949c1 on host 71 at 2104.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 87b95d4c-acee-4820-85e8-c4baee0d3a88 on host 71 at 2104.7s.
# Adversary: Processed EXPLOIT_VULN 87b95d4c-acee-4820-85e8-c4baee0d3a88 on host 71 at 2108.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 89c76ee8-d486-4108-8fd5-7a4d7d114750 on host 71 at 2108.9s.
# Adversary: Processed EXPLOIT_VULN 89c76ee8-d486-4108-8fd5-7a4d7d114750 on host 71 at 2113.7s.
# Adversary: Start EXPLOIT_VULN c3ae1396-da9d-4350-846a-f1aa92881b7e on host 71 at 2113.7s.
# Adversary: Processed EXPLOIT_VULN c3ae1396-da9d-4350-846a-f1aa92881b7e on host 71 at 2114.9s.
# Adversary: Start EXPLOIT_VULN 677e2715-4774-4648-88bc-d1bda7aa48d9 on host 71 at 2114.9s.
# Adversary: Processed EXPLOIT_VULN 677e2715-4774-4648-88bc-d1bda7aa48d9 on host 71 at 2120.2s.
# Adversary: Start EXPLOIT_VULN 946d9515-10de-4563-acba-2fad3a561edc on host 71 at 2120.2s.
# MTD: CompleteTopologyShuffle finished in 120.3s at 2123.3s.
# MTD: Interrupted EXPLOIT_VULN at 2123.3s!
# Adversary: Restarting with SCAN_HOST at 2143.4s!
# Adversary: Start SCAN_HOST at 2143.4s.
# Adversary: Processed SCAN_HOST at 2148.4s.
# Adversary: Start ENUM_HOST at 2148.4s.
# Adversary: Processed ENUM_HOST at 2153.4s.
# Adversary: Start SCAN_PORT at 2153.4s.
# Adversary: Processed SCAN_PORT at 2178.4s.
# Adversary: Start BRUTE_FORCE at 2178.4s.
# Adversary: Processed BRUTE_FORCE at 2198.4s.
# Adversary: Start ENUM_HOST at 2198.4s.
# MTD: IPShuffle triggered 2203.2s
# MTD: IPShuffle deployed in the network at 2203.2s.
# Adversary: Processed ENUM_HOST at 2203.4s.
# Adversary: Start SCAN_PORT at 2203.4s.
# Adversary: Processed SCAN_PORT at 2228.4s.
# Adversary: Start EXPLOIT_VULN f09776eb-ded0-4fa1-ae64-2c13b7b57589 on host 30 at 2228.4s.
# Adversary: Processed EXPLOIT_VULN f09776eb-ded0-4fa1-ae64-2c13b7b57589 on host 30 at 2228.7s.
# Adversary: Start EXPLOIT_VULN e1e035b7-9cc1-48c9-a0e4-86d208def0c1 on host 30 at 2228.7s.
# Adversary: Processed EXPLOIT_VULN e1e035b7-9cc1-48c9-a0e4-86d208def0c1 on host 30 at 2230.5s.
# Adversary: Start EXPLOIT_VULN 0a7a1940-5c32-45af-a346-0f005b9bc47c on host 30 at 2230.5s.
# Adversary: Processed EXPLOIT_VULN 0a7a1940-5c32-45af-a346-0f005b9bc47c on host 30 at 2236.3s.
# Adversary: Start EXPLOIT_VULN 34b0597f-bdb3-415b-b651-34efef3aa4cd on host 30 at 2236.3s.
# Adversary: Processed EXPLOIT_VULN 34b0597f-bdb3-415b-b651-34efef3aa4cd on host 30 at 2242.3s.
# Adversary: Start EXPLOIT_VULN ef543de5-a104-434f-b2f1-fa1f0bcfdf28 on host 30 at 2242.3s.
# Adversary: Processed EXPLOIT_VULN ef543de5-a104-434f-b2f1-fa1f0bcfdf28 on host 30 at 2250.3s.
# Adversary: Start EXPLOIT_VULN 543c8bd4-2963-4a13-986f-567e62d2a534 on host 30 at 2250.3s.
# Adversary: Processed EXPLOIT_VULN 543c8bd4-2963-4a13-986f-567e62d2a534 on host 30 at 2251.4s.
# Adversary: Start EXPLOIT_VULN 9b40d520-1797-44c7-ab3a-9c4507f7e917 on host 30 at 2251.4s.
# Adversary: Processed EXPLOIT_VULN 9b40d520-1797-44c7-ab3a-9c4507f7e917 on host 30 at 2254.5s.
# Adversary: Start EXPLOIT_VULN cfe876ac-9976-4de6-93d9-8935954a4f1c on host 30 at 2254.5s.
# Adversary: Processed EXPLOIT_VULN cfe876ac-9976-4de6-93d9-8935954a4f1c on host 30 at 2264.0s.
# Adversary: Start EXPLOIT_VULN 677afda3-c36a-4397-9dbb-927b1e4c413a on host 30 at 2264.0s.
# Adversary: Processed EXPLOIT_VULN 677afda3-c36a-4397-9dbb-927b1e4c413a on host 30 at 2266.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2cdf53d2-a2f5-4581-8f59-0aa5681d7876 on host 30 at 2266.9s.
# Adversary: Processed EXPLOIT_VULN 2cdf53d2-a2f5-4581-8f59-0aa5681d7876 on host 30 at 2273.9s.
# Adversary: Start EXPLOIT_VULN 94aad5d0-e2e1-4cb8-a29b-81b378a9eb3e on host 30 at 2273.9s.
# Adversary: Processed EXPLOIT_VULN 94aad5d0-e2e1-4cb8-a29b-81b378a9eb3e on host 30 at 2295.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5aacef2e-ed0a-449c-8422-6c87545e0a4c on host 30 at 2295.0s.
# Adversary: Processed EXPLOIT_VULN 5aacef2e-ed0a-449c-8422-6c87545e0a4c on host 30 at 2301.9s.
# Adversary: Start EXPLOIT_VULN 69f78599-28c5-4b95-9d19-2d9eca1da02b on host 30 at 2301.9s.
# Adversary: Processed EXPLOIT_VULN 69f78599-28c5-4b95-9d19-2d9eca1da02b on host 30 at 2307.3s.
# Adversary: Start EXPLOIT_VULN 0360081e-17b4-4891-9592-168e721463c1 on host 30 at 2307.3s.
# MTD: IPShuffle finished in 110.6s at 2313.8s.
# MTD: Interrupted EXPLOIT_VULN at 2313.8s!
# Adversary: Restarting with SCAN_HOST at 2334.4s!
# Adversary: Start SCAN_HOST at 2334.4s.
# Adversary: Processed SCAN_HOST at 2339.4s.
# Adversary: Start ENUM_HOST at 2339.4s.
# Adversary: Processed ENUM_HOST at 2344.4s.
# Adversary: Start SCAN_PORT at 2344.4s.
# Adversary: Processed SCAN_PORT at 2369.4s.
# Adversary: Start BRUTE_FORCE at 2369.4s.
# Adversary: Processed BRUTE_FORCE at 2389.4s.
# Adversary: Start ENUM_HOST at 2389.4s.
# Adversary: Processed ENUM_HOST at 2394.4s.
# Adversary: Start SCAN_PORT at 2394.4s.
# MTD: IPShuffle triggered 2403.5s
# MTD: IPShuffle deployed in the network at 2403.5s.
# Adversary: Processed SCAN_PORT at 2419.4s.
# Adversary: Start EXPLOIT_VULN 8af60814-b965-4673-83d5-b96a6bf4431d on host 33 at 2419.4s.
# Adversary: Processed EXPLOIT_VULN 8af60814-b965-4673-83d5-b96a6bf4431d on host 33 at 2420.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 95cb4f30-a299-4988-964d-ac7444dc3121 on host 33 at 2420.4s.
# Adversary: Processed EXPLOIT_VULN 95cb4f30-a299-4988-964d-ac7444dc3121 on host 33 at 2422.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 33 at 2422.6s.
# Adversary: Processed EXPLOIT_VULN 94e78dc2-6b57-4e48-80de-48b2b9e48506 on host 33 at 2444.0s.
# Adversary: Start EXPLOIT_VULN 2220951e-90a5-45a0-98cb-72f54b52e63a on host 33 at 2444.0s.
# Adversary: Processed EXPLOIT_VULN 2220951e-90a5-45a0-98cb-72f54b52e63a on host 33 at 2449.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7d8c94fa-1eab-438d-9efd-ea4276aa2db9 on host 33 at 2449.7s.
# Adversary: Processed EXPLOIT_VULN 7d8c94fa-1eab-438d-9efd-ea4276aa2db9 on host 33 at 2453.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9ba4a55e-8fe4-4eaa-8635-b618f766b512 on host 33 at 2453.0s.
# Adversary: Processed EXPLOIT_VULN 9ba4a55e-8fe4-4eaa-8635-b618f766b512 on host 33 at 2466.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a28325dd-f511-4bee-bbf0-1ebad4aaf06d on host 33 at 2466.6s.
# Adversary: Processed EXPLOIT_VULN a28325dd-f511-4bee-bbf0-1ebad4aaf06d on host 33 at 2478.5s.
# Adversary: Start EXPLOIT_VULN e802bc9c-fbac-4c1a-abed-ba1be6e7dc89 on host 33 at 2478.5s.
# Adversary: Processed EXPLOIT_VULN e802bc9c-fbac-4c1a-abed-ba1be6e7dc89 on host 33 at 2486.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 61337693-662d-4fa0-a823-c0794f495d48 on host 33 at 2486.7s.
# Adversary: Processed EXPLOIT_VULN 61337693-662d-4fa0-a823-c0794f495d48 on host 33 at 2490.7s.
# Adversary: Start EXPLOIT_VULN 8534a7db-2c22-49bd-8f45-f50f6850a9a0 on host 33 at 2490.7s.
# Adversary: Processed EXPLOIT_VULN 8534a7db-2c22-49bd-8f45-f50f6850a9a0 on host 33 at 2497.7s.
# Adversary: Start EXPLOIT_VULN 26c5bacc-c665-4b81-b142-f31292170cac on host 33 at 2497.7s.
# Adversary: Processed EXPLOIT_VULN 26c5bacc-c665-4b81-b142-f31292170cac on host 33 at 2506.7s.
# Adversary: Start EXPLOIT_VULN a60e3534-fd38-4dc4-b3ae-cf94fc0a2447 on host 33 at 2506.7s.
# MTD: IPShuffle finished in 110.7s at 2514.2s.
# MTD: Interrupted EXPLOIT_VULN at 2514.2s!
# Adversary: Restarting with SCAN_HOST at 2536.0s!
# Adversary: Start SCAN_HOST at 2536.0s.
# Adversary: Processed SCAN_HOST at 2541.0s.
# Adversary: Start ENUM_HOST at 2541.0s.
# Adversary: Processed ENUM_HOST at 2546.0s.
# Adversary: Start SCAN_PORT at 2546.0s.
# Adversary: Processed SCAN_PORT at 2571.0s.
# Adversary: Start BRUTE_FORCE at 2571.0s.
# Adversary: Processed BRUTE_FORCE at 2591.0s.
# Adversary: Start ENUM_HOST at 2591.0s.
# Adversary: Processed ENUM_HOST at 2596.0s.
# Adversary: Start SCAN_PORT at 2596.0s.
# MTD: ServiceDiversity triggered 2603.9s
# MTD: ServiceDiversity deployed in the network at 2603.9s.
# Adversary: Processed SCAN_PORT at 2621.0s.
# Adversary: Start EXPLOIT_VULN 1d7c12d3-db5a-4fa8-84ec-acb57cfd9ffb on host 28 at 2621.0s.
# Adversary: Processed EXPLOIT_VULN 1d7c12d3-db5a-4fa8-84ec-acb57cfd9ffb on host 28 at 2621.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 174a9b19-ab86-4433-a153-5b62c8b0d088 on host 28 at 2621.7s.
# Adversary: Processed EXPLOIT_VULN 174a9b19-ab86-4433-a153-5b62c8b0d088 on host 28 at 2625.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ae96fc68-0c4c-44f1-a027-778df5fe31f7 on host 28 at 2625.7s.
# Adversary: Processed EXPLOIT_VULN ae96fc68-0c4c-44f1-a027-778df5fe31f7 on host 28 at 2628.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 37037381-636d-466e-8511-f5132b3b0d3c on host 28 at 2628.4s.
# Adversary: Processed EXPLOIT_VULN 37037381-636d-466e-8511-f5132b3b0d3c on host 28 at 2631.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 37d46aa4-36a2-4ef9-842d-04c474ea6bec on host 28 at 2631.5s.
# Adversary: Processed EXPLOIT_VULN 37d46aa4-36a2-4ef9-842d-04c474ea6bec on host 28 at 2637.2s.
# Adversary: Start EXPLOIT_VULN 677e2715-4774-4648-88bc-d1bda7aa48d9 on host 28 at 2637.2s.
# Adversary: Processed EXPLOIT_VULN 677e2715-4774-4648-88bc-d1bda7aa48d9 on host 28 at 2642.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 946d9515-10de-4563-acba-2fad3a561edc on host 28 at 2642.4s.
# Adversary: Processed EXPLOIT_VULN 946d9515-10de-4563-acba-2fad3a561edc on host 28 at 2655.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7cd19dcf-ce0e-4ea7-8502-51c4b4f77b04 on host 28 at 2655.3s.
# MTD: ServiceDiversity finished in 70.2s at 2674.1s.
# MTD: Interrupted EXPLOIT_VULN at 2674.1s!
# Adversary: Restarting with SCAN_PORT at 2694.5s!
# Adversary: Start SCAN_PORT at 2694.5s.
# Adversary: Processed SCAN_PORT at 2719.5s.
# Adversary: Start EXPLOIT_VULN 37d46aa4-36a2-4ef9-842d-04c474ea6bec on host 28 at 2719.5s.
# Adversary: Processed EXPLOIT_VULN 37d46aa4-36a2-4ef9-842d-04c474ea6bec on host 28 at 2725.2s.
# Adversary: Start EXPLOIT_VULN cca86151-0afe-4501-9910-cba03f71ea1c on host 28 at 2725.2s.
# Adversary: Processed EXPLOIT_VULN cca86151-0afe-4501-9910-cba03f71ea1c on host 28 at 2729.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5b92d52-5334-40e1-a602-1a4227421f38 on host 28 at 2729.2s.
# Adversary: Processed EXPLOIT_VULN f5b92d52-5334-40e1-a602-1a4227421f38 on host 28 at 2739.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cf49933c-1b1a-4c67-9d17-d860cb9ea956 on host 28 at 2739.1s.
# Adversary: Processed EXPLOIT_VULN cf49933c-1b1a-4c67-9d17-d860cb9ea956 on host 28 at 2744.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN eb2abd0e-8cdd-460b-aca7-760b08645f0e on host 28 at 2744.1s.
# Adversary: Processed EXPLOIT_VULN eb2abd0e-8cdd-460b-aca7-760b08645f0e on host 28 at 2752.1s.
# Adversary: Start EXPLOIT_VULN ddab632c-c22a-4b42-8972-e2b476a5e0cb on host 28 at 2752.1s.
# Adversary: Processed EXPLOIT_VULN ddab632c-c22a-4b42-8972-e2b476a5e0cb on host 28 at 2754.9s.
# Adversary: Start EXPLOIT_VULN 6bd71bfa-3f8a-4355-ac0f-d99c54477845 on host 28 at 2754.9s.
# Adversary: Processed EXPLOIT_VULN 6bd71bfa-3f8a-4355-ac0f-d99c54477845 on host 28 at 2767.0s.
# Adversary: Start EXPLOIT_VULN 77359db2-635e-4c5f-97f9-f240a9785c0d on host 28 at 2767.0s.
# Adversary: Processed EXPLOIT_VULN 77359db2-635e-4c5f-97f9-f240a9785c0d on host 28 at 2778.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 94cab4a8-5d97-4df4-9e58-4571c2efe86a on host 28 at 2778.9s.
# Adversary: Processed EXPLOIT_VULN 94cab4a8-5d97-4df4-9e58-4571c2efe86a on host 28 at 2787.4s.
# Adversary: Start EXPLOIT_VULN 9b5dbdc8-3f4c-43c4-8ed3-822f385ed754 on host 28 at 2787.4s.
# MTD: IPShuffle triggered 2804.1s
# MTD: IPShuffle deployed in the network at 2804.1s.
# Adversary: Processed EXPLOIT_VULN 9b5dbdc8-3f4c-43c4-8ed3-822f385ed754 on host 28 at 2808.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 95408d52-f59e-40b0-a859-a6a10f486be5 on host 28 at 2808.5s.
# Adversary: Processed EXPLOIT_VULN 95408d52-f59e-40b0-a859-a6a10f486be5 on host 28 at 2814.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN db5a680f-e759-4f84-8355-1c19567eb66f on host 28 at 2814.9s.
# Adversary: Processed EXPLOIT_VULN db5a680f-e759-4f84-8355-1c19567eb66f on host 28 at 2816.0s.
# Adversary: Start EXPLOIT_VULN 7ccfe8ed-3f0b-447f-8474-350fb80070d8 on host 28 at 2816.0s.
# Adversary: Processed EXPLOIT_VULN 7ccfe8ed-3f0b-447f-8474-350fb80070d8 on host 28 at 2818.7s.
# Adversary: Start EXPLOIT_VULN 065e4ea0-3372-49c2-b5af-a115cfba8e8c on host 28 at 2818.7s.
# Adversary: Processed EXPLOIT_VULN 065e4ea0-3372-49c2-b5af-a115cfba8e8c on host 28 at 2827.2s.
# Adversary: Start EXPLOIT_VULN 320e05b9-35ec-4759-b584-17bcafc4f150 on host 28 at 2827.2s.
# Adversary: Processed EXPLOIT_VULN 320e05b9-35ec-4759-b584-17bcafc4f150 on host 28 at 2832.2s.
# Adversary: Start EXPLOIT_VULN 4bf00239-04b9-483b-abe0-000138bac2dc on host 28 at 2832.2s.
# Adversary: Processed EXPLOIT_VULN 4bf00239-04b9-483b-abe0-000138bac2dc on host 28 at 2833.6s.
# Adversary: Start EXPLOIT_VULN 7a19d170-7a66-45d5-8b0d-d4b3e49cac45 on host 28 at 2833.6s.
# Adversary: Processed EXPLOIT_VULN 7a19d170-7a66-45d5-8b0d-d4b3e49cac45 on host 28 at 2835.1s.
# Adversary: Start EXPLOIT_VULN a57d4843-9576-4dbf-98fe-0af5041227cc on host 28 at 2835.1s.
# Adversary: Processed EXPLOIT_VULN a57d4843-9576-4dbf-98fe-0af5041227cc on host 28 at 2839.8s.
# Adversary: Start EXPLOIT_VULN 53d2f6f8-d134-4131-873e-15d8e0147840 on host 28 at 2839.8s.
# Adversary: Processed EXPLOIT_VULN 53d2f6f8-d134-4131-873e-15d8e0147840 on host 28 at 2848.0s.
# Adversary: Start EXPLOIT_VULN dca23540-299f-483e-91a5-97c58292a49b on host 28 at 2848.0s.
# Adversary: Processed EXPLOIT_VULN dca23540-299f-483e-91a5-97c58292a49b on host 28 at 2854.7s.
# Adversary: Start EXPLOIT_VULN eca47659-f09b-427c-9a50-244be9442099 on host 28 at 2854.7s.
# Adversary: Processed EXPLOIT_VULN eca47659-f09b-427c-9a50-244be9442099 on host 28 at 2856.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a28325dd-f511-4bee-bbf0-1ebad4aaf06d on host 28 at 2856.9s.
# Adversary: Processed EXPLOIT_VULN a28325dd-f511-4bee-bbf0-1ebad4aaf06d on host 28 at 2868.8s.
# Adversary: Start EXPLOIT_VULN 44730736-00ac-45fd-b97d-688731fd334f on host 28 at 2868.8s.
# Adversary: Processed EXPLOIT_VULN 44730736-00ac-45fd-b97d-688731fd334f on host 28 at 2886.0s.
# Adversary: Start EXPLOIT_VULN 82226801-6323-453e-a66e-ec713d96df6f on host 28 at 2886.0s.
# Adversary: Processed EXPLOIT_VULN 82226801-6323-453e-a66e-ec713d96df6f on host 28 at 2890.2s.
# Adversary: Start EXPLOIT_VULN 1f030d7e-c9cf-4d0e-9276-9deb1c851faf on host 28 at 2890.2s.
# Adversary: Processed EXPLOIT_VULN 1f030d7e-c9cf-4d0e-9276-9deb1c851faf on host 28 at 2897.8s.
# Adversary: Start EXPLOIT_VULN 2cdf53d2-a2f5-4581-8f59-0aa5681d7876 on host 28 at 2897.8s.
# MTD: IPShuffle finished in 110.6s at 2914.7s.
# MTD: Interrupted EXPLOIT_VULN at 2914.7s!
# Adversary: Restarting with SCAN_HOST at 2935.2s!
# Adversary: Start SCAN_HOST at 2935.2s.
# Adversary: Processed SCAN_HOST at 2940.2s.
# Adversary: Start ENUM_HOST at 2940.2s.
# Adversary: Processed ENUM_HOST at 2945.2s.
# Adversary: Start SCAN_PORT at 2945.2s.
# Adversary: Processed SCAN_PORT at 2970.2s.
# Adversary: Start BRUTE_FORCE at 2970.2s.
# Adversary: Processed BRUTE_FORCE at 2990.2s.
# Adversary: Start ENUM_HOST at 2990.2s.
# Adversary: Processed ENUM_HOST at 2995.2s.
# Adversary: Start SCAN_PORT at 2995.2s.
