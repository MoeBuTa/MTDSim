# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_simulation
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
evaluation = execute_ai_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100, new_network=True)
# Out:
# Static period: 0
# Action: 0
# Static period: 0
# Action: 1
# MTD: OSDiversity triggered 0.0s
# Static period: 119.78991892628324
# Action: 1
# MTD: CompleteTopologyShuffle triggered 200.0s
# MTD: Interrupted EXPLOIT_VULN at 320.3s!
# Static period: 80.22037891329717
# Action: 1
# MTD: IPShuffle triggered 400.5s
# MTD: Interrupted EXPLOIT_VULN at 510.8s!
# Static period: 90.80990995161483
# Action: 1
# MTD: ServiceDiversity triggered 601.6s
# Static period: 129.75822432264897
# Action: 1
# MTD: ServiceDiversity triggered 801.8s
# Static period: 130.88254556817515
# Action: 1
# MTD: ServiceDiversity triggered 1002.9s
# Static period: 129.98329850703135
# Action: 1
# MTD: ServiceDiversity triggered 1203.2s
# Static period: 127.86859303618985
# Action: 1
# MTD: OSDiversity triggered 1403.4s
# Static period: 119.78254804038352
# Action: 1
# MTD: OSDiversity triggered 1603.4s
# Static period: 119.67029892204391
# Action: 1
# MTD: ServiceDiversity triggered 1803.8s
# Static period: 129.96579579555055
# Action: 1
# MTD: IPShuffle triggered 2004.0s
# MTD: Interrupted SCAN_PORT at 2115.8s!
# Static period: 89.18286385356896
# Action: 1
# MTD: ServiceDiversity triggered 2205.0s
# Static period: 129.87647042363415
# Action: 1
# MTD: IPShuffle triggered 2405.1s
# MTD: Interrupted SCAN_PORT at 2515.3s!
# Static period: 89.96685719552033
# Action: 0
# Static period: 89.96685719552033
# Action: 0
# Static period: 89.96685719552033
# Action: 1
# MTD: ServiceDiversity triggered 2605.2s
# Static period: 130.32532583022976
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2805.6s
# MTD: Interrupted SCAN_NEIGHBOR at 2926.0s!

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100, new_network=True)
# Out:
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.0
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.425436507936508
# Attack Success Rate: 0
# MTD Frequency: 0
# Time to Compromise: 0
# Time Since Last MTD: 0
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 121.0s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.0
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4202579365079366
# Attack Success Rate: 0
# MTD Frequency: 0.008265044271635043
# Time to Compromise: 0
# Time Since Last MTD: 200.27011735162694
# MTD: IPShuffle triggered 200.3s
# MTD: Interrupted SCAN_PORT at 310.4s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.02
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.41828968253968246
# Attack Success Rate: 0.375
# MTD Frequency: 0.006442414685641865
# Time to Compromise: 308.272297836776
# Time Since Last MTD: 200.02652510835406
# MTD: ServiceDiversity triggered 400.3s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.02
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.43458333333333343
# Attack Success Rate: 0.29166666666666663
# MTD Frequency: 0.006374079587155036
# Time to Compromise: 398.58146478542346
# Time Since Last MTD: 200.35858511348675
# MTD: ServiceDiversity triggered 600.7s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.03
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4373214285714285
# Attack Success Rate: 0.3214285714285714
# MTD Frequency: 0.005961360169158697
# Time to Compromise: 537.9582386707822
# Time Since Last MTD: 201.15878402684302
# MTD: IPShuffle triggered 801.8s
# MTD: Interrupted SCAN_PORT at 911.9s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.05
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4354920634920635
# Attack Success Rate: 0.36214285714285716
# MTD Frequency: 0.005483076194364105
# Time to Compromise: 664.6747878428075
# Time Since Last MTD: 200.59696356838776
# MTD: CompleteTopologyShuffle triggered 1002.4s
# MTD: Interrupted EXPLOIT_VULN at 1122.8s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.05
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4406865079365078
# Attack Success Rate: 0.3454761904761905
# MTD Frequency: 0.005343915060846699
# Time to Compromise: 699.5299280402479
# Time Since Last MTD: 200.64821201273458
# MTD: IPShuffle triggered 1203.1s
# MTD: Interrupted EXPLOIT_VULN at 1314.1s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.06
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4429404761904761
# Attack Success Rate: 0.3454761904761905
# MTD Frequency: 0.00532682465271742
# Time to Compromise: 706.2011190110476
# Time Since Last MTD: 201.2219903832647
# MTD: OSDiversity triggered 1404.3s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.06
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.41890476190476195
# Attack Success Rate: 0.3454761904761905
# MTD Frequency: 0.005389616465385793
# Time to Compromise: 706.2011190110476
# Time Since Last MTD: 200.39744433632222
# MTD: OSDiversity triggered 1604.7s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.06
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4304444444444445
# Attack Success Rate: 0.3454761904761905
# MTD Frequency: 0.005337679213802673
# Time to Compromise: 706.2011190110476
# Time Since Last MTD: 200.04559835141436
# MTD: OSDiversity triggered 1804.7s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.06
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.46974603174603174
# Attack Success Rate: 0.3454761904761905
# MTD Frequency: 0.005304243322638414
# Time to Compromise: 706.2011190110476
# Time Since Last MTD: 200.19106168899225
# MTD: IPShuffle triggered 2004.9s
# MTD: Interrupted SCAN_NEIGHBOR at 2115.2s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.07
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4686626984126984
# Attack Success Rate: 0.3560124049619848
# MTD Frequency: 0.005200510932593048
# Time to Compromise: 1013.8301806891401
# Time Since Last MTD: 200.66786423366466
# MTD: CompleteTopologyShuffle triggered 2205.6s
# MTD: Interrupted EXPLOIT_VULN at 2325.6s!
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.08
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.43682539682539684
# Attack Success Rate: 0.3615108543417367
# MTD Frequency: 0.005159937024921564
# Time to Compromise: 1135.515268647695
# Time Since Last MTD: 200.0472536893817
# MTD: OSDiversity triggered 2405.6s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.08
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4208571428571428
# Attack Success Rate: 0.3591299019607843
# MTD Frequency: 0.005228466201446815
# Time to Compromise: 1156.31359837878
# Time Since Last MTD: 200.31793770481545
# MTD: OSDiversity triggered 2605.9s
# STATS BEFORE MTD OPERATION
# Host Compromise Ratio: 0.08
# Num Exposed Endpoints: 5
# Attack Path Exposure Score: 0.4346468253968255
# Attack Success Rate: 0.35696539979628217
# MTD Frequency: 0.005212280207089128
# Time to Compromise: 1179.3820791903663
# Time Since Last MTD: 200.10031767767305
# MTD: OSDiversity triggered 2806.0s
