# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_training
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
# Environment and agent settings
state_size = 7  # HCR, Exposed Endpoints, Attack Success Rate, Attack Path Exposure Score, Return on Attack Score, Attack Path Variability, Risk
time_series_size = 3  # Time Since Last MTD, MTTC, mtd_freqency
action_size = 5  # Deploy or don't deploy MTD technique  

# Learning Parameters
gamma = 0.95  # discount rate
epsilon = 1.0  # exploration rate
epsilon_min = 0.01
epsilon_decay = 0.995
batch_size = 32
train_start = 1000
episodes = 100

# Simulator Settings
start_time = 0
finish_time = 3000
mtd_interval = 200
scheme = 'mtd_ai'
total_nodes = 100
new_network = True

# %%
execute_ai_training(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, state_size=state_size, time_series_size=time_series_size, action_size=action_size, gamma=gamma, epsilon=epsilon, epsilon_min=epsilon_min, epsilon_decay=epsilon_decay, batch_size=batch_size, train_start=train_start, scheme=scheme, total_nodes=total_nodes, new_network=new_network, episodes=episodes)
# Out:
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 124.4s!
# Static period: 76.55469816408323
# Action: 0
# Static period: 76.55469816408323
# Action: 3
# MTD: CompleteTopologyShuffle triggered 200.9s
# MTD: Interrupted EXPLOIT_VULN at 321.4s!
# Static period: 80.08036625404196
# Action: 2
# MTD: CompleteTopologyShuffle triggered 401.5s
# MTD: Interrupted EXPLOIT_VULN at 521.5s!
# Static period: 80.48546504385786
# Action: 2
# MTD: CompleteTopologyShuffle triggered 602.0s
# MTD: Interrupted SCAN_PORT at 722.2s!
# Static period: 80.27547512320234
# Action: 3
# MTD: OSDiversity triggered 802.5s
# Static period: 120.63090383710335
# Action: 1
# MTD: OSDiversity triggered 1003.2s
# Static period: 117.30811377302211
# Action: 1
# MTD: OSDiversity triggered 1203.5s
# Static period: 120.4454584020184
# Action: 1
# MTD: OSDiversity triggered 1404.4s
# Static period: 120.76460747954798
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1605.2s
# MTD: Interrupted EXPLOIT_VULN at 1725.6s!
# Static period: 79.79537892085477
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1805.4s
# MTD: Interrupted EXPLOIT_VULN at 1926.0s!
# Static period: 79.58378085267668
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2005.6s
# MTD: Interrupted BRUTE_FORCE at 2126.9s!
# Static period: 79.96134632111489
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2206.9s
# MTD: Interrupted EXPLOIT_VULN at 2327.2s!
# Static period: 79.85677903784199
# Action: 0
# Static period: 79.85677903784199
# Action: 4
# MTD: ServiceDiversity triggered 2407.0s
# Static period: 129.1887345464388
# Action: 1
# MTD: ServiceDiversity triggered 2607.2s
# Static period: 129.83683770374182
# Action: 1
# MTD: ServiceDiversity triggered 2807.5s
# Episode: 0, Epsilon: 0.995
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 130.69270436948113
# Action: 1
# MTD: ServiceDiversity triggered 201.1s
# Static period: 129.3116050649698
# Action: 1
# MTD: ServiceDiversity triggered 401.1s
# Static period: 129.38545573349137
# Action: 1
# MTD: ServiceDiversity triggered 601.2s
# Static period: 131.15679113302576
# Action: 1
# MTD: CompleteTopologyShuffle triggered 802.5s
# MTD: Interrupted EXPLOIT_VULN at 922.6s!
# Static period: 81.13788677202888
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1003.7s
# MTD: Interrupted SCAN_NEIGHBOR at 1123.7s!
# Static period: 80.13382497792122
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1203.9s
# MTD: Interrupted EXPLOIT_VULN at 1324.3s!
# Static period: 79.82721372036872
# Action: 0
# Static period: 79.82721372036872
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1404.1s
# MTD: Interrupted EXPLOIT_VULN at 1524.3s!
# Static period: 80.69781023446649
# Action: 0
# Static period: 80.69781023446649
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1605.0s
# MTD: Interrupted EXPLOIT_VULN at 1725.3s!
# Static period: 79.81497364434426
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1805.1s
# MTD: Interrupted EXPLOIT_VULN at 1926.5s!
# Static period: 79.8757471620977
# Action: 0
# Static period: 79.8757471620977
# Action: 0
# Static period: 79.8757471620977
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2006.4s
# MTD: Interrupted EXPLOIT_VULN at 2126.6s!
# Static period: 81.02933254642585
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2207.6s
# MTD: Interrupted EXPLOIT_VULN at 2327.9s!
# Static period: 79.99442852406901
# Action: 4
# MTD: ServiceDiversity triggered 2407.9s
# Static period: 129.86449711119212
# Action: 1
# MTD: ServiceDiversity triggered 2608.0s
# Static period: 129.83306814111165
# Action: 1
# MTD: ServiceDiversity triggered 2808.1s
# Static period: 0
# Action: 0
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 130.71899761577725
# Action: 1
# MTD: ServiceDiversity triggered 201.0s
# Static period: 129.2025529861637
# Episode: 1, Epsilon: 0.990025
# Action: 1
# MTD: ServiceDiversity triggered 401.2s
# Static period: 130.1155577448252
# Action: 1
# MTD: ServiceDiversity triggered 601.7s
# Static period: 129.76630461317416
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.9s
# MTD: Interrupted SCAN_PORT at 922.5s!
# Static period: 79.51774444029365
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1002.0s
# MTD: Interrupted EXPLOIT_VULN at 1122.7s!
# Static period: 79.30968963169221
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1202.1s
# MTD: Interrupted ENUM_HOST at 1322.9s!
# Static period: 79.22301623746785
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1402.2s
# MTD: Interrupted BRUTE_FORCE at 1522.6s!
# Static period: 80.28570742859552
# Action: 0
# Static period: 80.28570742859552
# Action: 3
# MTD: OSDiversity triggered 1602.9s
# Static period: 120.07292221568264
# Action: 1
# MTD: OSDiversity triggered 1803.2s
# Static period: 119.4099683464085
# Action: 1
# MTD: OSDiversity triggered 2003.2s
# Static period: 119.7435442832766
# Action: 1
# MTD: OSDiversity triggered 2203.2s
# Static period: 118.37128114833331
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2403.3s
# MTD: Interrupted EXPLOIT_VULN at 2523.7s!
# Static period: 79.92470791087771
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2603.6s
# MTD: Interrupted EXPLOIT_VULN at 2726.7s!
# Static period: 77.4107497882651
# Action: 0
# Static period: 77.4107497882651
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2804.1s
# MTD: Interrupted ENUM_HOST at 2924.2s!
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 119.99254897374333
# Action: 1
# MTD: OSDiversity triggered 200.2s
# Episode: 2, Epsilon: 0.985074875
# Static period: 118.65239922782894
# Action: 1
# MTD: OSDiversity triggered 400.4s
# Static period: 120.27625069414603
# Action: 1
# MTD: OSDiversity triggered 600.9s
# Static period: 118.28087362476731
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.0s
# MTD: Interrupted EXPLOIT_VULN at 921.2s!
# Static period: 80.84460085127125
# Action: 0
# Static period: 80.84460085127125
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1002.1s
# MTD: Interrupted EXPLOIT_VULN at 1122.2s!
# Static period: 80.07796769957827
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1202.3s
# MTD: Interrupted SCAN_PORT at 1322.3s!
# Static period: 80.28719331824846
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1402.6s
# MTD: Interrupted EXPLOIT_VULN at 1523.2s!
# Static period: 80.27786450350686
# Action: 4
# MTD: ServiceDiversity triggered 1603.5s
# Static period: 129.18837458811458
# Action: 1
# MTD: ServiceDiversity triggered 1803.7s
# Static period: 131.48017444458992
# Action: 1
# MTD: ServiceDiversity triggered 2006.5s
# Static period: 129.64451567653305
# Action: 1
# MTD: ServiceDiversity triggered 2206.6s
# Static period: 129.13727813101195
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2406.7s
# MTD: Interrupted SCAN_PORT at 2527.1s!
# Static period: 80.26562620916502
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2607.4s
# MTD: Interrupted SCAN_PORT at 2727.9s!
# Static period: 79.90586814347762
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2807.8s
# MTD: Interrupted EXPLOIT_VULN at 2927.9s!
# Episode: 3, Epsilon: 0.9801495006250001
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 129.52699402386548
# Action: 1
# MTD: ServiceDiversity triggered 200.9s
# Static period: 131.19279725107282
# Action: 1
# MTD: ServiceDiversity triggered 402.3s
# Static period: 129.63717030437329
# Action: 1
# MTD: ServiceDiversity triggered 602.6s
# Static period: 131.10949290078815
# Action: 1
# MTD: CompleteTopologyShuffle triggered 804.5s
# MTD: Interrupted SCAN_PORT at 928.5s!
# Static period: 76.59599952053156
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1005.1s
# MTD: Interrupted EXPLOIT_VULN at 1125.6s!
# Static period: 80.23104013905731
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1205.8s
# MTD: Interrupted EXPLOIT_VULN at 1326.1s!
# Static period: 80.00645231769408
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1406.1s
# MTD: Interrupted EXPLOIT_VULN at 1526.4s!
# Static period: 79.77013680593586
# Action: 2
# MTD: IPShuffle triggered 1606.2s
# MTD: Interrupted EXPLOIT_VULN at 1716.2s!
# Static period: 91.89285181047171
# Action: 1
# MTD: IPShuffle triggered 1808.1s
# MTD: Interrupted BRUTE_FORCE at 1918.2s!
# Static period: 90.08722579187406
# Action: 3
# MTD: IPShuffle triggered 2008.2s
# MTD: Interrupted SCAN_PORT at 2118.3s!
# Static period: 90.31435173207137
# Action: 4
# MTD: IPShuffle triggered 2208.6s
# MTD: Interrupted EXPLOIT_VULN at 2318.6s!
# Static period: 90.02690737059993
# Action: 4
# MTD: ServiceDiversity triggered 2408.6s
# Static period: 129.94627078750182
# Action: 1
# MTD: ServiceDiversity triggered 2608.7s
# Static period: 130.37588856735692
# Action: 1
# MTD: ServiceDiversity triggered 2809.4s
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 120.13601972874704
# Action: 1
# MTD: OSDiversity triggered 201.0s
# Episode: 4, Epsilon: 0.9752487531218751
# Static period: 119.17267971679104
# Action: 1
# MTD: OSDiversity triggered 401.1s
# Static period: 120.0711134617352
# Action: 1
# MTD: OSDiversity triggered 601.5s
# Static period: 120.59731571314433
# Action: 1
# MTD: CompleteTopologyShuffle triggered 802.1s
# MTD: Interrupted BRUTE_FORCE at 923.3s!
# 1/1 [==============================] - 0s 117ms/step
# Static period: 79.76520597363128
# Action: 0
# Static period: 79.76520597363128
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1003.0s
# MTD: Interrupted ENUM_HOST at 1123.3s!
# Static period: 79.91895888764634
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1203.2s
# MTD: Interrupted EXPLOIT_VULN at 1323.3s!
# Static period: 80.03136118336579
# Action: 0
# Static period: 80.03136118336579
# Action: 0
# Static period: 80.03136118336579
# Action: 0
# Static period: 80.03136118336579
# Action: 0
# Static period: 80.03136118336579
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1403.3s
# MTD: Interrupted EXPLOIT_VULN at 1524.7s!
# Static period: 79.0704486264217
# Action: 0
# Static period: 79.0704486264217
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1603.8s
# MTD: Interrupted EXPLOIT_VULN at 1723.8s!
# Static period: 81.19839747193532
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1805.0s
# MTD: Interrupted EXPLOIT_VULN at 1925.5s!
# Static period: 79.6249944497381
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2005.1s
# MTD: Interrupted EXPLOIT_VULN at 2125.3s!
# Static period: 79.90229712452674
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2205.2s
# MTD: Interrupted EXPLOIT_VULN at 2326.1s!
# Static period: 79.50644071823854
# Action: 4
# MTD: ServiceDiversity triggered 2405.6s
# Static period: 129.95631001302218
# Action: 1
# MTD: ServiceDiversity triggered 2605.7s
# Static period: 130.27126208381605
# Action: 1
# MTD: ServiceDiversity triggered 2806.1s
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 120.54932659171031
# Action: 1
# MTD: OSDiversity triggered 200.6s
# Episode: 5, Epsilon: 0.9703725093562657
# Static period: 119.86232403180583
# Action: 1
# MTD: OSDiversity triggered 400.7s
# Static period: 120.0278781904318
# Action: 1
# MTD: OSDiversity triggered 601.2s
# Static period: 119.51470946247207
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.5s
# MTD: Interrupted EXPLOIT_VULN at 921.6s!
# Static period: 80.17016732595232
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1001.7s
# MTD: Interrupted EXPLOIT_VULN at 1122.5s!
# Static period: 79.48774064494864
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1201.9s
# MTD: Interrupted SCAN_NEIGHBOR at 1322.4s!
# Static period: 81.41317781140765
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1403.8s
# MTD: Interrupted EXPLOIT_VULN at 1524.4s!
# Static period: 80.44266945756362
# Action: 3
# MTD: OSDiversity triggered 1604.9s
# Static period: 120.3203158615404
# Action: 1
# MTD: OSDiversity triggered 1805.7s
# Static period: 119.74016347939323
# Action: 1
# MTD: OSDiversity triggered 2005.8s
# Static period: 119.45023970438933
# Action: 1
# MTD: OSDiversity triggered 2206.1s
# Static period: 119.86517482569843
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2406.7s
# MTD: Interrupted EXPLOIT_VULN at 2527.1s!
# Static period: 82.19965689314586
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2609.3s
# MTD: Interrupted SCAN_PORT at 2729.9s!
# Static period: 79.49834356187375
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2809.4s
# MTD: Interrupted EXPLOIT_VULN at 2929.9s!
# Episode: 6, Epsilon: 0.9655206468094844
# 1/1 [==============================] - 0s 119ms/step
# Static period: 0
# Action: 0
# Static period: 0
# Action: 2
# MTD: IPShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 110.8s!
# Static period: 89.76092789013636
# Action: 0
# Static period: 89.76092789013636
# Action: 4
# MTD: IPShuffle triggered 200.6s
# MTD: Interrupted EXPLOIT_VULN at 310.8s!
# Static period: 89.91986175038477
# Action: 4
# MTD: IPShuffle triggered 400.7s
# MTD: Interrupted EXPLOIT_VULN at 511.1s!
# Static period: 89.7091490766988
# Action: 2
# MTD: IPShuffle triggered 600.8s
# MTD: Interrupted EXPLOIT_VULN at 710.8s!
# Static period: 90.63105978956878
# Action: 3
# MTD: OSDiversity triggered 801.4s
# Static period: 120.1656908167721
# Action: 1
# MTD: OSDiversity triggered 1002.2s
# Static period: 119.70094233145824
# Action: 1
# MTD: OSDiversity triggered 1202.6s
# Static period: 119.93100956680723
# Action: 1
# MTD: OSDiversity triggered 1403.2s
# Static period: 119.81048716202417
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1603.5s
# MTD: Interrupted EXPLOIT_VULN at 1723.5s!
# Static period: 80.74157655909607
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1804.3s
# MTD: Interrupted SCAN_PORT at 1924.7s!
# Static period: 79.69516360076864
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2004.4s
# MTD: Interrupted EXPLOIT_VULN at 2124.7s!
# Static period: 80.43324395133823
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2205.2s
# MTD: Interrupted EXPLOIT_VULN at 2325.4s!
# Static period: 80.0449840659885
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2405.4s
# MTD: Interrupted EXPLOIT_VULN at 2525.5s!
# Static period: 80.2351587165922
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2605.8s
# MTD: Interrupted EXPLOIT_VULN at 2726.1s!
# Static period: 80.0948696826722
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2806.2s
# MTD: Interrupted EXPLOIT_VULN at 2929.3s!
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted SCAN_PORT at 120.4s!
# Static period: 79.98289829787382
# Action: 1
# MTD: CompleteTopologyShuffle triggered 200.4s
# MTD: Interrupted EXPLOIT_VULN at 320.7s!
# Static period: 79.70480336139804
# Episode: 7, Epsilon: 0.960693043575437
# Action: 3
# MTD: CompleteTopologyShuffle triggered 400.4s
# MTD: Interrupted EXPLOIT_VULN at 521.2s!
# Static period: 79.44716318108465
# Action: 3
# MTD: CompleteTopologyShuffle triggered 600.6s
# MTD: Interrupted EXPLOIT_VULN at 722.2s!
# Static period: 79.01284666938955
# Action: 2
# MTD: IPShuffle triggered 801.2s
# MTD: Interrupted EXPLOIT_VULN at 911.7s!
# Static period: 89.72383372343097
# Action: 3
# MTD: IPShuffle triggered 1001.4s
# MTD: Interrupted EXPLOIT_VULN at 1111.5s!
# Static period: 90.075412344602
# Action: 4
# MTD: IPShuffle triggered 1201.6s
# MTD: Interrupted SCAN_PORT at 1312.4s!
# Static period: 89.71067379377405
# Action: 2
# MTD: IPShuffle triggered 1402.1s
# MTD: Interrupted BRUTE_FORCE at 1513.2s!
# Static period: 89.07900559948257
# Action: 0
# 1/1 [==============================] - 0s 11ms/step
# Static period: 89.07900559948257
# Action: 0
# Static period: 89.07900559948257
# Action: 2
# MTD: IPShuffle triggered 1602.3s
# MTD: Interrupted EXPLOIT_VULN at 1713.2s!
# Static period: 91.39062060386982
# Action: 0
# Static period: 91.39062060386982
# Action: 1
# MTD: IPShuffle triggered 1804.6s
# MTD: Interrupted SCAN_PORT at 1915.4s!
# Static period: 89.64756556226916
# Action: 2
# MTD: IPShuffle triggered 2005.1s
# MTD: Interrupted EXPLOIT_VULN at 2115.3s!
# Static period: 90.11312532897637
# Action: 2
# MTD: IPShuffle triggered 2205.4s
# MTD: Interrupted EXPLOIT_VULN at 2315.8s!
# Static period: 90.10261638858628
# Action: 4
# MTD: ServiceDiversity triggered 2405.9s
# Static period: 130.19344998599354
# Action: 1
# MTD: ServiceDiversity triggered 2606.3s
# Static period: 129.80718116524258
# Action: 1
# MTD: ServiceDiversity triggered 2806.3s
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 129.44330247132925
# Action: 1
# MTD: ServiceDiversity triggered 200.3s
# Static period: 130.08645074799563
# Episode: 8, Epsilon: 0.9558895783575597
# Action: 1
# MTD: ServiceDiversity triggered 400.5s
# Static period: 129.08255141202358
# Action: 1
# MTD: ServiceDiversity triggered 600.8s
# Static period: 130.04218497637896
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.6s
# MTD: Interrupted EXPLOIT_VULN at 921.9s!
# Static period: 79.96807351628956
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1001.9s
# MTD: Interrupted EXPLOIT_VULN at 1122.5s!
# Static period: 79.5972643984046
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1202.1s
# MTD: Interrupted EXPLOIT_VULN at 1322.6s!
# Static period: 80.23864912146792
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1402.8s
# MTD: Interrupted EXPLOIT_VULN at 1523.1s!
# Static period: 80.99483926699122
# Action: 2
# MTD: IPShuffle triggered 1604.1s
# MTD: Interrupted SCAN_NEIGHBOR at 1714.1s!
# Static period: 90.89150022871513
# Action: 1
# MTD: IPShuffle triggered 1805.0s
# MTD: Interrupted EXPLOIT_VULN at 1915.1s!
# Static period: 90.31210485382871
# Action: 4
# MTD: IPShuffle triggered 2005.4s
# MTD: Interrupted EXPLOIT_VULN at 2115.5s!
# Static period: 89.99399451636964
# Action: 1
# MTD: IPShuffle triggered 2205.5s
# MTD: Interrupted SCAN_PORT at 2315.9s!
# Static period: 92.02035019196546
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2407.9s
# MTD: Interrupted SCAN_PORT at 2528.0s!
# Static period: 81.12193227014859
# Action: 0
# Static period: 81.12193227014859
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2609.1s
# MTD: Interrupted EXPLOIT_VULN at 2730.3s!
# Static period: 78.95653142888295
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2809.3s
# MTD: Interrupted EXPLOIT_VULN at 2929.8s!
# Static period: 0
# Action: 0
# Static period: 0
# Action: 2
# MTD: IPShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 110.3s!
# Static period: 89.89121162487818
# Episode: 9, Epsilon: 0.9511101304657719
# Action: 1
# MTD: IPShuffle triggered 200.1s
# MTD: Interrupted EXPLOIT_VULN at 310.2s!
# Static period: 90.35520938194753
# Action: 2
# MTD: IPShuffle triggered 400.5s
# MTD: Interrupted EXPLOIT_VULN at 512.8s!
# Static period: 87.95804380698951
# Action: 0
# Static period: 87.95804380698951
# Action: 3
# MTD: IPShuffle triggered 600.7s
# MTD: Interrupted EXPLOIT_VULN at 710.8s!
# Static period: 90.23657723778172
# Action: 0
# Static period: 90.23657723778172
# Action: 2
# MTD: IPShuffle triggered 801.0s
# MTD: Interrupted EXPLOIT_VULN at 911.5s!
# Static period: 89.62648525831298
# Action: 3
# MTD: IPShuffle triggered 1001.1s
# MTD: Interrupted EXPLOIT_VULN at 1111.4s!
# Static period: 90.69109180493956
# Action: 4
# MTD: IPShuffle triggered 1202.1s
# MTD: Interrupted BRUTE_FORCE at 1312.2s!
# Static period: 93.73548280892692
# Action: 3
# MTD: IPShuffle triggered 1405.9s
# MTD: Interrupted EXPLOIT_VULN at 1516.0s!
# Static period: 90.50683125746014
# Action: 3
# MTD: OSDiversity triggered 1606.5s
# Static period: 120.1441973198423
# Action: 1
# MTD: OSDiversity triggered 1806.8s
# Static period: 120.08531993044335
# Action: 1
# MTD: OSDiversity triggered 2006.9s
# Static period: 119.9180076434236
# Action: 1
# MTD: OSDiversity triggered 2208.3s
# Static period: 119.96158574579295
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2408.5s
# MTD: Interrupted SCAN_PORT at 2528.6s!
# Static period: 80.15355484454267
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2608.7s
# MTD: Interrupted EXPLOIT_VULN at 2729.5s!
# Static period: 79.20902073580737
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2808.7s
# MTD: Interrupted EXPLOIT_VULN at 2929.2s!
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 120.7394660009556
# Action: 1
# MTD: OSDiversity triggered 200.9s
# Static period: 120.34318325934998
# Episode: 10, Epsilon: 0.946354579813443
# Action: 1
# MTD: OSDiversity triggered 401.3s
# Static period: 120.51168418289058
# Action: 1
# MTD: OSDiversity triggered 602.0s
# Static period: 120.61504026482203
# Action: 1
# MTD: CompleteTopologyShuffle triggered 802.9s
# MTD: Interrupted SCAN_PORT at 923.2s!
# Static period: 79.70815839490217
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1002.9s
# MTD: Interrupted EXPLOIT_VULN at 1124.0s!
# Static period: 79.2709772111375
# Action: 0
# Static period: 79.2709772111375
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1203.3s
# MTD: Interrupted EXPLOIT_VULN at 1324.2s!
# Static period: 79.24132429614065
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1403.5s
# MTD: Interrupted EXPLOIT_VULN at 1524.6s!
# Static period: 79.85281425940548
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1604.5s
# MTD: Interrupted EXPLOIT_VULN at 1724.5s!
# Static period: 81.34969799289138
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1805.9s
# MTD: Interrupted EXPLOIT_VULN at 1925.9s!
# Static period: 80.38189810616086
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2006.3s
# MTD: Interrupted EXPLOIT_VULN at 2126.4s!
# Static period: 80.55068868942135
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2206.9s
# MTD: Interrupted EXPLOIT_VULN at 2327.8s!
# Static period: 79.71413169189282
# Action: 4
# MTD: ServiceDiversity triggered 2407.5s
# Static period: 131.3044676454233
# Action: 1
# MTD: ServiceDiversity triggered 2609.1s
# Static period: 129.93406801875062
# Action: 1
# MTD: ServiceDiversity triggered 2809.1s
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 120.4s!
# Episode: 11, Epsilon: 0.9416228069143757
# Static period: 80.20495834431141
# Action: 3
# MTD: CompleteTopologyShuffle triggered 200.6s
# MTD: Interrupted SCAN_PORT at 320.7s!
# Static period: 80.81267818962789
# Action: 3
# MTD: CompleteTopologyShuffle triggered 401.5s
# MTD: Interrupted BRUTE_FORCE at 521.5s!
# Static period: 81.76192923275755
# Action: 2
# MTD: CompleteTopologyShuffle triggered 603.2s
# MTD: Interrupted SCAN_PORT at 724.3s!
# Static period: 79.00271418045236
# Action: 2
# MTD: IPShuffle triggered 803.3s
# MTD: Interrupted SCAN_PORT at 913.9s!
# Static period: 90.02396587487408
# Action: 1
# MTD: IPShuffle triggered 1003.9s
# MTD: Interrupted EXPLOIT_VULN at 1114.5s!
# Static period: 91.15261588612543
# Action: 4
# MTD: IPShuffle triggered 1205.7s
# MTD: Interrupted EXPLOIT_VULN at 1316.4s!
# Static period: 89.31060873216597
# Action: 3
# MTD: IPShuffle triggered 1405.7s
# MTD: Interrupted SCAN_PORT at 1518.2s!
# Static period: 87.48374199217074
# Action: 0
# Static period: 87.48374199217074
# Action: 4
# MTD: ServiceDiversity triggered 1605.7s
# Static period: 129.8188924062722
# Action: 1
# MTD: ServiceDiversity triggered 1805.8s
# Static period: 130.20239328199932
# Action: 1
# MTD: ServiceDiversity triggered 2006.0s
# Static period: 130.13924408672665
# Action: 1
# MTD: ServiceDiversity triggered 2206.3s
# Static period: 130.57247313057314
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2406.9s
# MTD: Interrupted EXPLOIT_VULN at 2527.5s!
# Static period: 80.09290272859789
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2607.5s
# MTD: Interrupted SCAN_PORT at 2728.5s!
# Static period: 80.19200413864246
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2808.7s
# MTD: Interrupted EXPLOIT_VULN at 2928.9s!
# Episode: 12, Epsilon: 0.9369146928798039
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 120.2s!
# Static period: 80.21320965263492
# Action: 1
# MTD: CompleteTopologyShuffle triggered 200.4s
# MTD: Interrupted EXPLOIT_VULN at 320.4s!
# Static period: 81.9872149954756
# Action: 3
# MTD: CompleteTopologyShuffle triggered 402.4s
# MTD: Interrupted EXPLOIT_VULN at 523.1s!
# Static period: 79.36647238995045
# Action: 2
# MTD: CompleteTopologyShuffle triggered 602.5s
# MTD: Interrupted EXPLOIT_VULN at 722.8s!
# Static period: 80.33106692405966
# Action: 2
# MTD: IPShuffle triggered 803.1s
# MTD: Interrupted EXPLOIT_VULN at 915.7s!
# Static period: 87.5118109705902
# Action: 2
# MTD: IPShuffle triggered 1003.2s
# MTD: Interrupted EXPLOIT_VULN at 1114.1s!
# Static period: 89.56353127213356
# Action: 0
# Static period: 89.56353127213356
# Action: 1
# MTD: IPShuffle triggered 1203.6s
# MTD: Interrupted EXPLOIT_VULN at 1313.7s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 90.30522006937417
# Action: 0
# Static period: 90.30522006937417
# Action: 0
# 1/1 [==============================] - 0s 11ms/step
# Static period: 90.30522006937417
# Action: 0
# Static period: 90.30522006937417
# Action: 0
# Static period: 90.30522006937417
# Action: 1
# MTD: IPShuffle triggered 1404.0s
# MTD: Interrupted EXPLOIT_VULN at 1514.2s!
# Static period: 90.13031581318364
# Action: 4
# MTD: ServiceDiversity triggered 1604.3s
# Static period: 129.7943724014915
# Action: 1
# MTD: ServiceDiversity triggered 1804.9s
# Static period: 129.73546250155823
# Action: 1
# MTD: ServiceDiversity triggered 2005.3s
# Static period: 130.38568035915705
# Action: 1
# MTD: ServiceDiversity triggered 2205.9s
# Static period: 130.35552791574264
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2407.2s
# MTD: Interrupted SCAN_PORT at 2527.5s!
# Static period: 80.73162543737453
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2608.2s
# MTD: Interrupted SCAN_PORT at 2728.8s!
# Static period: 79.63087687915095
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2808.4s
# MTD: Interrupted EXPLOIT_VULN at 2929.4s!
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 130.2305174510871
# Action: 1
# MTD: ServiceDiversity triggered 200.6s
# Static period: 127.6079903082491
# Episode: 13, Epsilon: 0.9322301194154049
# Action: 1
# MTD: ServiceDiversity triggered 400.7s
# Static period: 130.3540408236047
# Action: 1
# MTD: ServiceDiversity triggered 601.4s
# Static period: 129.0376886087364
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.7s
# MTD: Interrupted EXPLOIT_VULN at 921.7s!
# Static period: 81.1990415519017
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1002.9s
# MTD: Interrupted EXPLOIT_VULN at 1123.5s!
# 1/1 [==============================] - 0s 10ms/step
# Static period: 79.6411052065921
# Action: 0
# Static period: 79.6411052065921
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1203.1s
# MTD: Interrupted EXPLOIT_VULN at 1323.1s!
# Static period: 80.18008773081306
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1403.3s
# MTD: Interrupted EXPLOIT_VULN at 1524.5s!
# Static period: 78.91224742244503
# Action: 3
# MTD: OSDiversity triggered 1603.4s
# Static period: 118.67482751685338
# Action: 1
# MTD: OSDiversity triggered 1803.5s
# Static period: 119.55999637819104
# Action: 1
# MTD: OSDiversity triggered 2003.6s
# Static period: 120.22443943169174
# Action: 1
# MTD: OSDiversity triggered 2203.9s
# Static period: 119.6030977016444
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2404.1s
# MTD: Interrupted EXPLOIT_VULN at 2524.4s!
# Static period: 80.17614218959761
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2604.6s
# MTD: Interrupted EXPLOIT_VULN at 2724.7s!
# Static period: 79.88425394071373
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2804.6s
# MTD: Interrupted ENUM_HOST at 2924.6s!
# Static period: 0
# Action: 2
# MTD: IPShuffle triggered 0.0s
# MTD: Interrupted ENUM_HOST at 110.3s!
# Static period: 90.1141207999956
# Action: 0
# Static period: 90.1141207999956
# Action: 0
# Static period: 90.1141207999956
# Action: 4
# MTD: IPShuffle triggered 200.4s
# MTD: Interrupted EXPLOIT_VULN at 310.7s!
# Static period: 89.9743616791718
# Action: 4
# MTD: IPShuffle triggered 400.6s
# MTD: Interrupted EXPLOIT_VULN at 510.8s!
# Static period: 90.98538576178976
# Action: 3
# MTD: IPShuffle triggered 601.8s
# MTD: Interrupted EXPLOIT_VULN at 712.0s!
# Static period: 90.06277901597934
# Episode: 14, Epsilon: 0.9275689688183278
# Action: 3
# MTD: OSDiversity triggered 802.1s
# Static period: 119.32111972716928
# Action: 1
# MTD: OSDiversity triggered 1002.1s
# Static period: 120.97679337561499
# Action: 1
# MTD: OSDiversity triggered 1203.2s
# Static period: 120.24707523293978
# Action: 1
# MTD: OSDiversity triggered 1403.6s
# Static period: 119.68965690456025
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1603.7s
# MTD: Interrupted EXPLOIT_VULN at 1724.3s!
# Static period: 80.33321763787603
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1804.7s
# MTD: Interrupted SCAN_PORT at 1925.3s!
# Static period: 79.58369894503676
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2004.9s
# MTD: Interrupted EXPLOIT_VULN at 2124.9s!
# 1/1 [==============================] - 0s 10ms/step
# Static period: 80.57567040687127
# Action: 0
# Static period: 80.57567040687127
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2205.5s
# MTD: Interrupted EXPLOIT_VULN at 2325.5s!
# Static period: 79.97352129295314
# Action: 0
# Static period: 79.97352129295314
# Action: 2
# MTD: IPShuffle triggered 2405.5s
# MTD: Interrupted EXPLOIT_VULN at 2516.3s!
# Static period: 89.58590909869554
# Action: 0
# Static period: 89.58590909869554
# Action: 0
# Static period: 89.58590909869554
# Action: 2
# MTD: IPShuffle triggered 2605.9s
# MTD: Interrupted EXPLOIT_VULN at 2716.3s!
# Static period: 90.17262901398226
# Action: 2
# MTD: IPShuffle triggered 2806.5s
# MTD: Interrupted EXPLOIT_VULN at 2916.6s!
# Episode: 15, Epsilon: 0.9229311239742362
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 121.0s!
# Static period: 79.36770666425464
# Action: 4
# MTD: CompleteTopologyShuffle triggered 200.4s
# MTD: Interrupted EXPLOIT_VULN at 320.6s!
# Static period: 80.04660545610517
# Action: 2
# MTD: CompleteTopologyShuffle triggered 400.7s
# MTD: Interrupted EXPLOIT_VULN at 521.1s!
# Static period: 79.76421792244571
# Action: 3
# MTD: CompleteTopologyShuffle triggered 600.8s
# MTD: Interrupted EXPLOIT_VULN at 722.1s!
# Static period: 79.17181353753006
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.3s
# MTD: Interrupted EXPLOIT_VULN at 921.8s!
# Static period: 79.96545096434329
# Action: 0
# Static period: 79.96545096434329
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1001.8s
# MTD: Interrupted EXPLOIT_VULN at 1122.0s!
# Static period: 80.74020875987003
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1202.7s
# MTD: Interrupted SCAN_PORT at 1323.1s!
# Static period: 79.7615089341748
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1402.8s
# MTD: Interrupted EXPLOIT_VULN at 1524.0s!
# Static period: 79.79249857584523
# Action: 3
# MTD: OSDiversity triggered 1603.8s
# Static period: 120.21429658720604
# Action: 1
# MTD: OSDiversity triggered 1804.1s
# Static period: 119.23441035332075
# Action: 1
# MTD: OSDiversity triggered 2004.2s
# Static period: 119.60517029734547
# Action: 1
# MTD: OSDiversity triggered 2204.6s
# Static period: 119.41103215723615
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2404.6s
# MTD: Interrupted EXPLOIT_VULN at 2524.7s!
# 1/1 [==============================] - 0s 10ms/step
# Static period: 80.22138951808529
# Action: 0
# Static period: 80.22138951808529
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2604.9s
# MTD: Interrupted SCAN_PORT at 2725.3s!
# Static period: 79.64847767261472
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2805.0s
# MTD: Interrupted ENUM_HOST at 2925.0s!
# Episode: 16, Epsilon: 0.918316468354365
# Static period: 0
# Action: 2
# MTD: IPShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 110.2s!
# Static period: 90.04984514873084
# Action: 3
# MTD: IPShuffle triggered 200.3s
# MTD: Interrupted EXPLOIT_VULN at 312.2s!
# Static period: 88.8543339075714
# Action: 4
# MTD: IPShuffle triggered 401.0s
# MTD: Interrupted EXPLOIT_VULN at 511.7s!
# Static period: 89.62103965205387
# Action: 4
# MTD: IPShuffle triggered 601.3s
# MTD: Interrupted EXPLOIT_VULN at 711.5s!
# Static period: 89.81324559869176
# Action: 2
# MTD: IPShuffle triggered 801.3s
# MTD: Interrupted EXPLOIT_VULN at 911.8s!
# Static period: 89.71967532103008
# Action: 0
# 1/1 [==============================] - 0s 10ms/step
# Static period: 89.71967532103008
# Action: 0
# 1/1 [==============================] - 0s 11ms/step
# Static period: 89.71967532103008
# Action: 0
# Static period: 89.71967532103008
# Action: 1
# MTD: IPShuffle triggered 1001.6s
# MTD: Interrupted EXPLOIT_VULN at 1112.3s!
# Static period: 89.29572048945374
# Action: 0
# 1/1 [==============================] - 0s 11ms/step
# Static period: 89.29572048945374
# Action: 0
# Static period: 89.29572048945374
# Action: 4
# MTD: IPShuffle triggered 1201.6s
# MTD: Interrupted SCAN_PORT at 1312.0s!
# Static period: 89.9478658683654
# Action: 0
# Static period: 89.9478658683654
# Action: 4
# MTD: IPShuffle triggered 1402.0s
# MTD: Interrupted EXPLOIT_VULN at 1512.2s!
# Static period: 90.0091340537449
# Action: 4
# MTD: ServiceDiversity triggered 1602.2s
# Static period: 129.47649957803947
# Action: 1
# MTD: ServiceDiversity triggered 1802.7s
# Static period: 128.7834202806739
# Action: 1
# MTD: ServiceDiversity triggered 2003.3s
# Static period: 129.03941786258156
# Action: 1
# MTD: ServiceDiversity triggered 2203.5s
# Static period: 130.00419026308873
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2403.6s
# MTD: Interrupted EXPLOIT_VULN at 2523.7s!
# Static period: 80.62721408000061
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2604.3s
# MTD: Interrupted EXPLOIT_VULN at 2725.7s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 79.41274998067274
# Action: 0
# Static period: 79.41274998067274
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2805.1s
# MTD: Interrupted EXPLOIT_VULN at 2925.1s!
# Static period: 0
# Action: 1
# Episode: 17, Epsilon: 0.9137248860125932
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 120.1s!
# Static period: 80.56169447020699
# Action: 2
# MTD: CompleteTopologyShuffle triggered 200.6s
# MTD: Interrupted SCAN_PORT at 320.7s!
# Static period: 81.2268589636206
# Action: 4
# MTD: CompleteTopologyShuffle triggered 401.9s
# MTD: Interrupted EXPLOIT_VULN at 522.2s!
# Static period: 79.69456940708233
# Action: 3
# MTD: CompleteTopologyShuffle triggered 601.9s
# MTD: Interrupted EXPLOIT_VULN at 721.9s!
# Static period: 79.98959673739967
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.9s
# MTD: Interrupted EXPLOIT_VULN at 922.0s!
# Static period: 80.60367515402208
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1002.6s
# MTD: Interrupted SCAN_PORT at 1123.6s!
# Static period: 79.43842482823061
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1203.1s
# MTD: Interrupted ENUM_HOST at 1323.1s!
# Static period: 80.03652502079012
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1403.1s
# MTD: Interrupted EXPLOIT_VULN at 1523.5s!
# Static period: 81.98333204702908
# Action: 4
# MTD: ServiceDiversity triggered 1605.5s
# Static period: 130.0681956444064
# Action: 1
# MTD: ServiceDiversity triggered 1805.6s
# Static period: 130.25496404646674
# Action: 1
# MTD: ServiceDiversity triggered 2006.7s
# Static period: 130.10540743015645
# Action: 1
# MTD: ServiceDiversity triggered 2206.8s
# Static period: 129.88695113157928
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2407.0s
# MTD: Interrupted EXPLOIT_VULN at 2527.2s!
# Static period: 79.86934832702536
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2607.1s
# MTD: Interrupted ENUM_HOST at 2727.4s!
# Static period: 80.36233832657854
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2807.7s
# MTD: Interrupted ENUM_HOST at 2929.0s!
# Episode: 18, Epsilon: 0.9091562615825302
# Static period: 0
# Action: 0
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 119.2954417841977
# Action: 1
# MTD: OSDiversity triggered 200.7s
# Static period: 121.31618645403518
# Action: 1
# MTD: OSDiversity triggered 402.2s
# Static period: 120.14465978872437
# Action: 1
# MTD: OSDiversity triggered 602.4s
# Static period: 119.83937633976382
# Action: 1
# MTD: CompleteTopologyShuffle triggered 803.0s
# MTD: Interrupted EXPLOIT_VULN at 923.9s!
# Static period: 80.89286177565668
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1004.8s
# MTD: Interrupted EXPLOIT_VULN at 1125.5s!
# Static period: 79.541216139884
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1205.1s
# MTD: Interrupted EXPLOIT_VULN at 1325.2s!
# Static period: 80.28263907076462
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1405.5s
# MTD: Interrupted EXPLOIT_VULN at 1525.7s!
# Static period: 80.52447004898909
# Action: 0
# Static period: 80.52447004898909
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1606.2s
# MTD: Interrupted EXPLOIT_VULN at 1726.4s!
# Static period: 79.86362929094798
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1806.3s
# MTD: Interrupted EXPLOIT_VULN at 1926.8s!
# Static period: 80.62428962596005
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2007.4s
# MTD: Interrupted EXPLOIT_VULN at 2127.6s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 79.90915236028059
# Action: 0
# Static period: 79.90915236028059
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2207.5s
# MTD: Interrupted EXPLOIT_VULN at 2327.9s!
# Static period: 80.29656644386523
# Action: 4
# MTD: ServiceDiversity triggered 2408.2s
# Static period: 129.30470340545435
# Action: 1
# MTD: ServiceDiversity triggered 2608.9s
# Static period: 129.02650191271005
# Action: 1
# MTD: ServiceDiversity triggered 2808.9s
# Episode: 19, Epsilon: 0.9046104802746175
# Static period: 0
# Action: 0
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted EXPLOIT_VULN at 120.3s!
# 1/1 [==============================] - 0s 10ms/step
# Static period: 79.9906348919882
# Action: 0
# Static period: 79.9906348919882
# Action: 2
# MTD: CompleteTopologyShuffle triggered 200.3s
# MTD: Interrupted EXPLOIT_VULN at 320.6s!
# Static period: 79.80090900641864
# Action: 0
# Static period: 79.80090900641864
# Action: 2
# MTD: CompleteTopologyShuffle triggered 400.4s
# MTD: Interrupted EXPLOIT_VULN at 522.0s!
# Static period: 78.89531737795392
# Action: 2
# MTD: CompleteTopologyShuffle triggered 600.9s
# MTD: Interrupted EXPLOIT_VULN at 721.4s!
# Static period: 80.1610983268099
# Action: 2
# MTD: IPShuffle triggered 801.6s
# MTD: Interrupted SCAN_PORT at 911.8s!
# Static period: 90.3426947394073
# Action: 2
# MTD: IPShuffle triggered 1002.2s
# MTD: Interrupted EXPLOIT_VULN at 1112.4s!
# Static period: 90.65220776584715
# Action: 4
# MTD: IPShuffle triggered 1203.1s
# MTD: Interrupted EXPLOIT_VULN at 1313.1s!
# Static period: 90.31841397805306
# Action: 2
# MTD: IPShuffle triggered 1403.4s
# MTD: Interrupted EXPLOIT_VULN at 1514.2s!
# Static period: 90.41723255534203
# Action: 4
# MTD: ServiceDiversity triggered 1604.6s
# Static period: 130.14771527560606
# Action: 1
# MTD: ServiceDiversity triggered 1805.1s
# Static period: 129.80049781236676
# Action: 1
# MTD: ServiceDiversity triggered 2005.5s
# Static period: 130.27440080789484
# Action: 1
# MTD: ServiceDiversity triggered 2206.3s
# Static period: 130.10957706278396
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2406.6s
# MTD: Interrupted EXPLOIT_VULN at 2527.7s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 80.85752886230921
# Action: 0
# Static period: 80.85752886230921
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2608.6s
# MTD: Interrupted EXPLOIT_VULN at 2728.8s!
# Static period: 80.2612326198755
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2809.1s
# MTD: Interrupted EXPLOIT_VULN at 2929.1s!
# Episode: 20, Epsilon: 0.9000874278732445
# Static period: 0
# Action: 3
# MTD: OSDiversity triggered 0.0s
# Static period: 121.47276340937783
# Action: 1
# MTD: OSDiversity triggered 202.0s
# Static period: 119.72103733628535
# Action: 1
# MTD: OSDiversity triggered 402.2s
# Static period: 120.19210500544744
# Action: 1
# MTD: OSDiversity triggered 602.4s
# Static period: 120.42101144382298
# Action: 1
# MTD: CompleteTopologyShuffle triggered 803.1s
# MTD: Interrupted EXPLOIT_VULN at 923.9s!
# Static period: 79.88697493986763
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1003.8s
# MTD: Interrupted EXPLOIT_VULN at 1124.3s!
# Static period: 79.59451275291758
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1203.9s
# MTD: Interrupted EXPLOIT_VULN at 1324.0s!
# Static period: 81.0156239493208
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1405.0s
# MTD: Interrupted EXPLOIT_VULN at 1526.0s!
# Static period: 79.02593801566786
# Action: 0
# Static period: 79.02593801566786
# Action: 4
# MTD: ServiceDiversity triggered 1605.0s
# Static period: 129.94625619457088
# Action: 1
# MTD: ServiceDiversity triggered 1805.2s
# Static period: 129.00559308727907
# Action: 1
# MTD: ServiceDiversity triggered 2005.4s
# Static period: 129.41344696132364
# Action: 1
# MTD: ServiceDiversity triggered 2205.4s
# Static period: 128.30979515288846
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2405.6s
# MTD: Interrupted EXPLOIT_VULN at 2525.7s!
# Static period: 80.10342413194576
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2605.8s
# MTD: Interrupted EXPLOIT_VULN at 2725.9s!
# Static period: 80.27612202013279
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2806.2s
# MTD: Interrupted SCAN_PORT at 2926.3s!
# Episode: 21, Epsilon: 0.8955869907338783
# Static period: 0
# Action: 2
# MTD: IPShuffle triggered 0.0s
# MTD: Interrupted SCAN_NEIGHBOR at 110.7s!
# Static period: 89.55304198784829
# Action: 2
# MTD: IPShuffle triggered 200.3s
# MTD: Interrupted BRUTE_FORCE at 311.0s!
# Static period: 89.28985300446766
# Action: 4
# MTD: IPShuffle triggered 400.3s
# MTD: Interrupted ENUM_HOST at 510.3s!
# Static period: 90.97053408361177
# Action: 3
# MTD: IPShuffle triggered 601.3s
# MTD: Interrupted EXPLOIT_VULN at 711.5s!
# Static period: 90.93644289517079
# Action: 1
# MTD: CompleteTopologyShuffle triggered 802.4s
# MTD: Interrupted EXPLOIT_VULN at 922.5s!
# Static period: 80.40584138384907
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1002.9s
# MTD: Interrupted SCAN_PORT at 1123.7s!
# Static period: 79.25849377557643
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1203.0s
# MTD: Interrupted EXPLOIT_VULN at 1323.0s!
# Static period: 80.66698801181246
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1403.7s
# MTD: Interrupted EXPLOIT_VULN at 1525.5s!
# Static period: 78.9515848939061
# Action: 3
# MTD: OSDiversity triggered 1604.5s
# Static period: 120.45787238382627
# Action: 1
# MTD: OSDiversity triggered 1805.0s
# Static period: 120.79157468694802
# Action: 1
# MTD: OSDiversity triggered 2005.9s
# Static period: 118.51337876047273
# Action: 1
# MTD: OSDiversity triggered 2206.0s
# Static period: 121.73232299151414
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2408.0s
# MTD: Interrupted EXPLOIT_VULN at 2528.9s!
# Static period: 79.175698439381
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2608.1s
# MTD: Interrupted ENUM_HOST at 2728.1s!
# Static period: 80.17310716270049
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2808.3s
# MTD: Interrupted EXPLOIT_VULN at 2929.3s!
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 130.50015134438644
# Action: 1
# MTD: ServiceDiversity triggered 200.6s
# Static period: 129.91151023606471
# Action: 1
# MTD: ServiceDiversity triggered 401.1s
# Episode: 22, Epsilon: 0.8911090557802088
# Static period: 130.44201600850784
# Action: 1
# MTD: ServiceDiversity triggered 601.6s
# Static period: 129.87509591366438
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.9s
# MTD: Interrupted EXPLOIT_VULN at 921.9s!
# Static period: 81.0051484198683
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1002.9s
# MTD: Interrupted EXPLOIT_VULN at 1123.0s!
# Static period: 80.04770284520646
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1203.1s
# MTD: Interrupted BRUTE_FORCE at 1323.6s!
# Static period: 79.75061787171921
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1403.3s
# MTD: Interrupted SCAN_PORT at 1523.6s!
# Static period: 79.80998767097367
# Action: 2
# MTD: IPShuffle triggered 1603.4s
# MTD: Interrupted EXPLOIT_VULN at 1713.8s!
# Static period: 90.14120002625259
# Action: 0
# Static period: 90.14120002625259
# Action: 4
# MTD: IPShuffle triggered 1803.9s
# MTD: Interrupted EXPLOIT_VULN at 1913.9s!
# Static period: 90.1727219331708
# Action: 0
# Static period: 90.1727219331708
# Action: 2
# MTD: IPShuffle triggered 2004.1s
# MTD: Interrupted EXPLOIT_VULN at 2114.3s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 90.69685158394077
# Action: 0
# Static period: 90.69685158394077
# Action: 0
# Static period: 90.69685158394077
# Action: 4
# MTD: IPShuffle triggered 2205.0s
# MTD: Interrupted EXPLOIT_VULN at 2315.4s!
# Static period: 89.89927058240028
# Action: 2
# MTD: IPShuffle triggered 2405.3s
# MTD: Interrupted EXPLOIT_VULN at 2515.7s!
# Static period: 89.68760442826897
# Action: 0
# Static period: 89.68760442826897
# Action: 0
# Static period: 89.68760442826897
# Action: 0
# Static period: 89.68760442826897
# Action: 3
# MTD: IPShuffle triggered 2605.4s
# MTD: Interrupted EXPLOIT_VULN at 2715.5s!
# 1/1 [==============================] - 0s 11ms/step
# Static period: 90.19819743755397
# Action: 0
# Static period: 90.19819743755397
# Action: 0
# Static period: 90.19819743755397
# Action: 3
# MTD: IPShuffle triggered 2805.7s
# MTD: Interrupted EXPLOIT_VULN at 2915.9s!
# Static period: 0
# Episode: 23, Epsilon: 0.8866535105013078
# Action: 0
# 1/1 [==============================] - 0s 11ms/step
# Static period: 0
# Action: 0
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: Interrupted ENUM_HOST at 120.0s!
# Static period: 81.17944857536203
# Action: 3
# MTD: CompleteTopologyShuffle triggered 201.2s
# MTD: Interrupted EXPLOIT_VULN at 321.5s!
# Static period: 81.57456112354055
# Action: 1
# MTD: CompleteTopologyShuffle triggered 403.0s
# MTD: Interrupted EXPLOIT_VULN at 523.4s!
# Static period: 80.59818548628107
# Action: 2
# MTD: CompleteTopologyShuffle triggered 604.0s
# MTD: Interrupted EXPLOIT_VULN at 724.4s!
# Static period: 79.82253774335265
# Action: 0
# Static period: 79.82253774335265
# Action: 1
# MTD: CompleteTopologyShuffle triggered 804.2s
# MTD: Interrupted EXPLOIT_VULN at 924.3s!
# Static period: 80.92103415058875
# Action: 0
# Static period: 80.92103415058875
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1005.2s
# MTD: Interrupted EXPLOIT_VULN at 1125.2s!
# Static period: 80.01286571718379
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1205.2s
# MTD: Interrupted EXPLOIT_VULN at 1325.9s!
# Static period: 80.15436846868101
# Action: 0
# Static period: 80.15436846868101
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1406.1s
# MTD: Interrupted SCAN_PORT at 1526.2s!
# Static period: 80.9977942878129
# Action: 4
# MTD: ServiceDiversity triggered 1607.2s
# Static period: 131.01490506641903
# Action: 1
# MTD: ServiceDiversity triggered 1808.2s
# Static period: 130.42013038823984
# Action: 1
# MTD: ServiceDiversity triggered 2008.8s
# Static period: 130.4844694184976
# Action: 1
# MTD: ServiceDiversity triggered 2209.3s
# Static period: 130.0642225214483
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2409.5s
# MTD: Interrupted EXPLOIT_VULN at 2529.8s!
# Static period: 79.79140473385814
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2609.6s
# MTD: Interrupted SCAN_PORT at 2729.8s!
# Static period: 80.53342910276069
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2810.3s
# MTD: Interrupted ENUM_HOST at 2930.8s!
# Episode: 24, Epsilon: 0.8822202429488013
# Static period: 0
# Action: 0
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 130.7774445270014
# Action: 1
# MTD: ServiceDiversity triggered 200.8s
# Static period: 129.12004336098119
# Action: 1
# MTD: ServiceDiversity triggered 401.0s
# Static period: 129.92309417391533
# Action: 1
# MTD: ServiceDiversity triggered 601.3s
# Static period: 129.0796970546753
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.3s
# MTD: Interrupted EXPLOIT_VULN at 921.6s!
# Static period: 80.47377224667696
# Action: 0
# Static period: 80.47377224667696
# Action: 0
# Static period: 80.47377224667696
# Action: 0
# Static period: 80.47377224667696
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1002.1s
# MTD: Interrupted EXPLOIT_VULN at 1122.5s!
# Static period: 82.24103465062421
# Action: 0
# Static period: 82.24103465062421
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1204.7s
# MTD: Interrupted SCAN_PORT at 1324.9s!
# Static period: 79.94492803643743
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1404.8s
# MTD: Interrupted EXPLOIT_VULN at 1525.2s!
# Static period: 79.6054774903248
# Action: 0
# Static period: 79.6054774903248
# Action: 3
# MTD: OSDiversity triggered 1604.8s
# Static period: 119.35167577481116
# Action: 1
# MTD: OSDiversity triggered 1805.5s
# Static period: 119.0538667366452
# Action: 1
# MTD: OSDiversity triggered 2005.6s
# Static period: 122.83803618948286
# Action: 1
# MTD: OSDiversity triggered 2208.7s
# Static period: 120.90176239177481
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2410.6s
# MTD: Interrupted EXPLOIT_VULN at 2531.0s!
# Static period: 79.68452125306976
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2610.7s
# MTD: Interrupted SCAN_PORT at 2730.9s!
# Static period: 80.50976206224732
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2811.4s
# MTD: Interrupted EXPLOIT_VULN at 2931.4s!
# Episode: 25, Epsilon: 0.8778091417340573
# 1/1 [==============================] - 0s 11ms/step
# Static period: 0
# Action: 0
# Static period: 0
# Action: 4
# MTD: ServiceDiversity triggered 0.0s
# Static period: 129.66926762415346
# Action: 1
# MTD: ServiceDiversity triggered 200.2s
# Static period: 130.0738492649901
# Action: 1
# MTD: ServiceDiversity triggered 400.4s
# Static period: 130.44670438261164
# Action: 1
# MTD: ServiceDiversity triggered 600.9s
# Static period: 130.07186492395147
# Action: 1
# MTD: CompleteTopologyShuffle triggered 801.3s
# MTD: Interrupted EXPLOIT_VULN at 921.5s!
# ...
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# Static period: 79.7495726427378
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2208.0s
# MTD: Interrupted SCAN_PORT at 2328.0s!
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# Static period: 80.5020854152067
# Action: 2
# MTD: IPShuffle triggered 2408.5s
# MTD: Interrupted EXPLOIT_VULN at 2519.2s!
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Static period: 89.41358880070129
# Action: 2
# MTD: IPShuffle triggered 2608.6s
# MTD: Interrupted EXPLOIT_VULN at 2718.9s!
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# Static period: 91.56737125404652
# Action: 3
# MTD: IPShuffle triggered 2810.4s
# MTD: Interrupted EXPLOIT_VULN at 2921.4s!
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# Episode: 99, Epsilon: 0.6057704364907278
# Training completed and model saved.

# %%
# evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100, new_network=True)
