# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_training
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
# Environment and agent settings
static_features = ["host_compromise_ratio", "exposed_endpoints", "attack_path_exposure",  "overall_asr_avg", "roa", "shortest_path_variability", "risk", "attack_type"]
time_features = ["mtd_freq", "overall_mttc_avg", "time_since_last_mtd"]
features = {"static": static_features, "time": time_features}
state_size = 8
time_series_size = 3 # Time Since Last MTD, MTTC, mtd_freqency
action_size = 5  # Deploy(4 types, 1-4) or don't deploy(0) MTD technique  

# Learning Parameters
gamma = 0.95  # discount rate
epsilon = 1.0  # exploration rate
epsilon_min = 0.01
epsilon_decay = 0.995
batch_size = 32
train_start = 1000
episodes = 100

# Simulator Settings
start_time = 0
finish_time = 5000
mtd_interval = 200
scheme = 'mtd_ai'
total_nodes = 100
new_network = True
file_name = "all_features"

# %%
# Train using all features
execute_ai_training(features = features, start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, state_size=state_size, time_series_size=time_series_size, action_size=action_size, gamma=gamma, epsilon=epsilon, epsilon_min=epsilon_min, epsilon_decay=epsilon_decay, batch_size=batch_size, train_start=train_start, scheme=scheme, total_nodes=total_nodes, new_network=new_network, episodes=episodes, file_name=file_name )
# Out:
# -244.05889781315722 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -3293.665728021978 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 3271.2912087912086 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -5.313644688644686 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 205.8418643140554 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 15.8611884976686 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 5.128205128205127 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -6.570512820512822 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.5705128205128234 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 6.282051282051277 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 617.1861451048951 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -1155.8880681818182 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 778.0861461881918 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 6.249999999999998 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.0 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.0 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -20.98214285714286 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -5.357142857142846 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 6.547619047619041 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -10.20833333333334 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.8749999999999933 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 12.500000000000014 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -2.0833333333333344 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 3.6792134166977686 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -28.874410686766307 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# Episode: 0, Epsilon: 0.995
# 0.3800595238095311 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 2.101785714285713 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -2.588988095238082 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.8574404761904825 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -38.10010387220076 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.8949404761904783 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.7833333333333276 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0
['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -130.96509141670234 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -19.706121156072413 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -491.5850719133808 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 910.5145338722609 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -546.7152030591419 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -1.2124999999999997 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.7818452380952339 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# Episode: 6, Epsilon: 0.9655206468094844
# -0.9211309523809524 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.8663690476190505 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -105.07233643511228 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.23214285714285715 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.750000000000007 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.21369047619046178 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.6964285714285798 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -109.40678675820281 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# -1.2895833333333426 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -3.1678571428571307 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# -2.6842261904761964 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -16.45039950250097 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.16785714285713627 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.40654761904762443 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -194.98603852039494 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -210.59645566657156 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 740.8875295601548 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -553.22788041734 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -26.495879412166914 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1.3166666666666618 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.3886904761904758 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.21088447061048365 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.1500000000000024 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.5749999999999991 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -103.29303790675874 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# Episode: 7, Epsilon: 0.960693043575437
# 1.7857142857142878 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -223.58587238362 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.0 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -45.01610659546358 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 2362.04375 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -2324.330654761905 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -3.0047619047618976 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.3297619047618966 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.0 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.41250000000000453 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.0 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.004464285714284033 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 400.29725318111986 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.7895833333333393 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.826488095238099 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.7758928571428578 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# -5.16488095238096 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 131.34926154490594 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 7.762500000000007 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1610.163670770103 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 6.231845238095243 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -1727.61213798636 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# -41.753278316582396 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 63.30393409384146 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -142.04277579422563 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# Episode: 8, Epsilon: 0.9558895783575597
# 0.3392857142857156 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -267.9038499446277 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.2898809523809512 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 173.58568159873232 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1.2488095238095311 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -115.72944310699101 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 2.1095238095238082 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.011309523809534261 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -1.924702380952377 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -688.2344652646184 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# -40.27480099390453 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.4807692307692374 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 540.4990842490844 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1094.0477252440207 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -698.6979166666666 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.6318452380952522 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.11428571428570705 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.047916666666664165 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 5.392261904761905 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -3.618749999999997 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -27.20551937413957 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -6.750485352338023 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.02083333333333659 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 96.03660973826895 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.7500000000000007 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# Episode: 9, Epsilon: 0.9511101304657719
# -0.0023809523809495414 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.8898809523809517 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -68.31888115599368 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -0.26994047619048056 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2.14255952380952 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -2.2261904761904607 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 8.546705271004532 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -3.3970238095238208 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# -6.299892524317336 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.007142857142852788 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 0.7122023809523981 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 0.343154761904757 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1.0699404761904798 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# -939.4202380952381 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1746.540476190476 ['host_compromise_ratio', 'exposed_endpoints', 'attack_path_exposure', 'overall_asr_avg', 'roa', 'shortest_path_variability', 'risk', 'attack_type'] ['mtd_freq']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# static_features = ["host_compromise_ratio", "exposed_endpoints", "attack_path_exposure",  "overall_asr_avg", "roa", "shortest_path_variability", "risk", "attack_type"]
time_features = ["mtd_freq"]
features = {"static": static_features, "time": time_features}
execute_ai_training(features = features, start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, state_size=state_size, time_series_size=time_series_size, action_size=action_size, gamma=gamma, epsilon=epsilon, epsilon_min=epsilon_min, epsilon_decay=epsilon_decay, batch_size=batch_size, train_start=train_start, scheme=scheme, total_nodes=total_nodes, new_network=new_network, episodes=episodes, file_name=feature)
